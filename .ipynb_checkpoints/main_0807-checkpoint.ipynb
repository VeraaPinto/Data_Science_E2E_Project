# %% [markdown]
# # Import Libraries

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor,AdaBoostRegressor, GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error, make_scorer, mean_squared_error, mean_absolute_percentage_error
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score, KFold
from scipy.stats import randint, uniform

# %%
df1 = pd.read_csv("/Users/verapinto/Desktop/Final_Project/Data_Science_E2E_Project/Forecast.csv")
df1.head()
# Out:
#   Month-Year  PRODUCT_FAMILY    GMID    LOC Country Sales    Forecast    MAPE  \
# 0     23-Jul               6  600001  KR001      KR   909  868.279179   4.50%
# 1     23-Aug               6  600001  KR001      KR   786  867.675973  10.40%
# 2     23-Sep               6  600001  KR001      KR   846  906.330589   7.10%
# 3     23-Oct               6  600001  KR001      KR   761  907.327425  19.20%
# 4     23-Nov               6  600001  KR001      KR   786  868.000000  10.40%
#
#   MAPE_Impact MAPE_Contribution  Absolute Error  Non Absolute Error
# 0       0.00%             0.00%       40.720821          -40.720821
# 1       0.01%             0.00%       81.675973           81.675973
# 2       0.01%             0.00%       60.330590           60.330590
# 3       0.01%             0.10%      146.327425          146.327425
# 4       0.01%             0.00%       82.000000           82.000000

# %%
df1.shape
# Out:
# (18159, 12)

# %%
df2 = pd.read_csv("/Users/verapinto/Desktop/Final_Project/Data_Science_E2E_Project/Stocks.csv")
df2.head()
# Out:
#    Product.Family    GMID GMID_Description     Market      Geography  \
# 0               6  600001     06 2.9MG/5ML      Korea  International
# 1               6  600002     06 2.9MG/5ML  Hong Kong  Greater China
# 2               6  600003     06 2.9MG/5ML     Canada  North America
# 3               6  600004     06 2.9MG/5ML   Malaysia  International
# 4               6  600005     06 500IU/5ML  Australia  International
#
#   Material.Type.GMID    Date  Coverage   Min   Max
# 0                 FG  23-Jul      1.82  2.73  4.91
# 1                 FG  23-Jul      3.09  2.86  5.68
# 2                 FG  23-Jul      3.41  2.73  5.68
# 3                 FG  23-Jul      0.91  3.18  9.14
# 4                 FG  23-Jul      0.91  2.73  4.59

# %%
df2.shape
# Out:
# (24234, 10)

# %%
df_geo  = pd.read_csv("/Users/verapinto/Desktop/Final_Project/Data_Science_E2E_Project/Countries_Geo.csv")
df_geo.head()
# Out:
#   Country_Key     Country_Desc      Geography
# 0          AL          Albania            NaN
# 1          DZ          Algeria  International
# 2          VI  Amer.Virgin Is.            NaN
# 3          AR        Argentina  International
# 4          AU        Australia  International

# %%
df_md  = pd.read_csv("/Users/verapinto/Desktop/Final_Project/Data_Science_E2E_Project/MD.csv")
df_md.head()
# Out:
#      GMID Market  PRODUCT_FAMILY DOSAGE_STRENGTH MATERIAL_TYPE LSD_STATUS  \
# 0  150167     CY              15  200 MG/1,14 ML            FG         No
# 1  150024     EC              15     300 MG/2 ML            FG         No
# 2  150002     CH              15     300 MG/2 ML            FG         No
# 3  800009     TW               8          400 IU            FG         No
# 4  150098     OM              15     300 MG/2 ML            FG     Global
#
#   MCO_SEGMENTATION STRATEGY_SEGMENTATION SMART_SEGMENTATION
# 0      Regular MCO          Auto Piloted      Supply Growth
# 1      Regular MCO          Auto Piloted      Supply Growth
# 2          Top MCO              Platinum      Supply Growth
# 3      Regular MCO                  Gold             Secure
# 4      Regular MCO              Platinum      Supply Growth

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Merge Datasets

# %% [markdown]
# #### Merge df1 ( sales, forecast, mape, absolute error information) with df_geo to append Market and Geography column

# %%
# Merge df1 with country metadata to add Country_Desc and Geography columns
df1_enriched = df1.merge(
    df_geo[['Country_Key', 'Country_Desc', 'Geography']],
    left_on='Country',
    right_on='Country_Key',
    how='left'  # Preserves all rows from df1
)
df1_enriched.drop(columns='Country_Key', inplace=True)
df1_enriched.head()
# Out:
#   Month-Year  PRODUCT_FAMILY    GMID    LOC Country Sales    Forecast    MAPE  \
# 0     23-Jul               6  600001  KR001      KR   909  868.279179   4.50%
# 1     23-Aug               6  600001  KR001      KR   786  867.675973  10.40%
# 2     23-Sep               6  600001  KR001      KR   846  906.330589   7.10%
# 3     23-Oct               6  600001  KR001      KR   761  907.327425  19.20%
# 4     23-Nov               6  600001  KR001      KR   786  868.000000  10.40%
#
#   MAPE_Impact MAPE_Contribution  Absolute Error  Non Absolute Error  \
# 0       0.00%             0.00%       40.720821          -40.720821
# 1       0.01%             0.00%       81.675973           81.675973
# 2       0.01%             0.00%       60.330590           60.330590
# 3       0.01%             0.10%      146.327425          146.327425
# 4       0.01%             0.00%       82.000000           82.000000
#
#   Country_Desc      Geography
# 0        Korea  International
# 1        Korea  International
# 2        Korea  International
# 3        Korea  International
# 4        Korea  International

# %%
# check duplication of rows after merge
print("Before merge:", len(df1))
print("After merge:", len(df1_enriched))
# Out:
# Before merge: 18159
# After merge: 18159

# %%
# Change column Month-Year to Date in df1 and df2
df1_enriched.rename(columns={'Month-Year': 'Date'}, inplace=True)

# Standardize keys in both dataframes
df1_enriched['Date'] = df1_enriched['Date'].astype(str).str.strip().str.strip("'").str.title()
df1_enriched['Date'] = pd.to_datetime(df1_enriched['Date'], format='%y-%b', errors='coerce')

df2['Date'] = df2['Date'].astype(str).str.strip().str.title()
df2['Date'] = pd.to_datetime(df2['Date'], format='%y-%b', errors='coerce')

# %% [markdown]
# #### Identify and resolve duplicate records in df2

# %%
#check duplicates
# Check if GMID + Date + Country_Key appear only once
duplicates = df2.duplicated(subset=['GMID', 'Date', 'Market'])
print("Duplicate rows in df2:", duplicates.sum())
# Out:
# Duplicate rows in df2: 495

# %%
#Define key columns and priority rows (non-null coverage, min, max)

# Replace NaNs with 0 for comparison
df2['Coverage'] = df2['Coverage'].fillna(0)
df2['Min'] = df2['Min'].fillna(0)
df2['Max'] = df2['Max'].fillna(0)

# Mark rows with valid (non-zero) values
df2['has_data'] = (df2['Coverage'] > 0) | (df2['Min'] > 0) | (df2['Max'] > 0)

#Sort to valid rows come first
df2 = df2.sort_values(by='has_data', ascending=False)

#Drop duplicates by keeping the first one (which now has valid values)
df2 = df2.drop_duplicates(subset=['GMID', 'Date', 'Market'], keep='first')

#Drop helper column
df2.drop(columns='has_data', inplace=True)

# %%
# double check duplicated rows
df2.duplicated(subset=['GMID', 'Date', 'Market']).sum()
# Out:
# 0

# %% [markdown]
# #### Merge df1 (main dataset) with df2 (stock levels information)

# %%
# Merge 2 tables
df_merged = df1_enriched.merge(
    df2[['GMID', 'Date', 'Market', 'Coverage', 'Min', 'Max']],
    left_on=['GMID', 'Date', 'Country_Desc'],
    right_on=['GMID', 'Date', 'Market'],
    how='left'
)

df_merged.drop(columns=['MAPE_Impact','MAPE_Contribution', 'Non Absolute Error', 'Market'], inplace=True)
df_merged.head()
# Out:
#         Date  PRODUCT_FAMILY    GMID    LOC Country Sales    Forecast    MAPE  \
# 0 2023-07-01               6  600001  KR001      KR   909  868.279179   4.50%
# 1 2023-08-01               6  600001  KR001      KR   786  867.675973  10.40%
# 2 2023-09-01               6  600001  KR001      KR   846  906.330589   7.10%
# 3 2023-10-01               6  600001  KR001      KR   761  907.327425  19.20%
# 4 2023-11-01               6  600001  KR001      KR   786  868.000000  10.40%
#
#    Absolute Error Country_Desc      Geography  Coverage   Min   Max
# 0       40.720821        Korea  International      1.82  2.73  4.91
# 1       81.675973        Korea  International      4.27  2.73  4.91
# 2       60.330590        Korea  International      3.27  2.73  4.91
# 3      146.327425        Korea  International      2.27  2.73  4.91
# 4       82.000000        Korea  International      3.23  2.73  4.91

# %%
#check duplication of rows after merge
print("Before merge:", len(df1_enriched))
print("After merge:", len(df_merged))
# Out:
# Before merge: 18159
# After merge: 18159

# %% [markdown]
# #### Merge df1 (main dataset) with df3 (market and product segmentation information)

# %%
df_smart = df_md[['PRODUCT_FAMILY', 'SMART_SEGMENTATION']].drop_duplicates()

df1_smart = df_merged.merge(
    df_smart,
    on='PRODUCT_FAMILY',
    how='left'
)
df1_smart.head()
# Out:
#         Date  PRODUCT_FAMILY    GMID    LOC Country Sales    Forecast    MAPE  \
# 0 2023-07-01               6  600001  KR001      KR   909  868.279179   4.50%
# 1 2023-08-01               6  600001  KR001      KR   786  867.675973  10.40%
# 2 2023-09-01               6  600001  KR001      KR   846  906.330589   7.10%
# 3 2023-10-01               6  600001  KR001      KR   761  907.327425  19.20%
# 4 2023-11-01               6  600001  KR001      KR   786  868.000000  10.40%
#
#    Absolute Error Country_Desc      Geography  Coverage   Min   Max  \
# 0       40.720821        Korea  International      1.82  2.73  4.91
# 1       81.675973        Korea  International      4.27  2.73  4.91
# 2       60.330590        Korea  International      3.27  2.73  4.91
# 3      146.327425        Korea  International      2.27  2.73  4.91
# 4       82.000000        Korea  International      3.23  2.73  4.91
#
#   SMART_SEGMENTATION
# 0             Secure
# 1             Secure
# 2             Secure
# 3             Secure
# 4             Secure

# %%
#check duplication of rows after merge
print("Before merge:", len(df_merged))
print("After merge:", len(df1_smart))
# Out:
# Before merge: 18159
# After merge: 18159

# %%
df_mco = df_md[['Market', 'MCO_SEGMENTATION']].drop_duplicates()

df1_mco = df1_smart.merge(
    df_mco,
    left_on='Country',
    right_on='Market',
    how='left'
).drop(columns=['Market'])  # Optional: remove Market after merge
df1_mco.head()
# Out:
#         Date  PRODUCT_FAMILY    GMID    LOC Country Sales    Forecast    MAPE  \
# 0 2023-07-01               6  600001  KR001      KR   909  868.279179   4.50%
# 1 2023-08-01               6  600001  KR001      KR   786  867.675973  10.40%
# 2 2023-09-01               6  600001  KR001      KR   846  906.330589   7.10%
# 3 2023-10-01               6  600001  KR001      KR   761  907.327425  19.20%
# 4 2023-11-01               6  600001  KR001      KR   786  868.000000  10.40%
#
#    Absolute Error Country_Desc      Geography  Coverage   Min   Max  \
# 0       40.720821        Korea  International      1.82  2.73  4.91
# 1       81.675973        Korea  International      4.27  2.73  4.91
# 2       60.330590        Korea  International      3.27  2.73  4.91
# 3      146.327425        Korea  International      2.27  2.73  4.91
# 4       82.000000        Korea  International      3.23  2.73  4.91
#
#   SMART_SEGMENTATION MCO_SEGMENTATION
# 0             Secure        Major MCO
# 1             Secure        Major MCO
# 2             Secure        Major MCO
# 3             Secure        Major MCO
# 4             Secure        Major MCO

# %%
#check duplication of rows after merge
print("Before merge:", len(df_merged))
print("After merge:", len(df1_mco))
# Out:
# Before merge: 18159
# After merge: 18159

# %%
df_strategy = df_md[['GMID', 'Market', 'STRATEGY_SEGMENTATION']].drop_duplicates()

df_final = df1_mco.merge(
    df_strategy,
    left_on=['GMID', 'Country'],
    right_on=['GMID', 'Market'],
    how='left'
).drop(columns=['Market'])  # Again, drop Market if it’s redundant
df_final.head()
# Out:
#         Date  PRODUCT_FAMILY    GMID    LOC Country Sales    Forecast    MAPE  \
# 0 2023-07-01               6  600001  KR001      KR   909  868.279179   4.50%
# 1 2023-08-01               6  600001  KR001      KR   786  867.675973  10.40%
# 2 2023-09-01               6  600001  KR001      KR   846  906.330589   7.10%
# 3 2023-10-01               6  600001  KR001      KR   761  907.327425  19.20%
# 4 2023-11-01               6  600001  KR001      KR   786  868.000000  10.40%
#
#    Absolute Error Country_Desc      Geography  Coverage   Min   Max  \
# 0       40.720821        Korea  International      1.82  2.73  4.91
# 1       81.675973        Korea  International      4.27  2.73  4.91
# 2       60.330590        Korea  International      3.27  2.73  4.91
# 3      146.327425        Korea  International      2.27  2.73  4.91
# 4       82.000000        Korea  International      3.23  2.73  4.91
#
#   SMART_SEGMENTATION MCO_SEGMENTATION STRATEGY_SEGMENTATION
# 0             Secure        Major MCO              Platinum
# 1             Secure        Major MCO              Platinum
# 2             Secure        Major MCO              Platinum
# 3             Secure        Major MCO              Platinum
# 4             Secure        Major MCO              Platinum

# %%
#check duplication of rows after merge
print("Before merge:", len(df_merged))
print("After merge:", len(df_final))
# Out:
# Before merge: 18159
# After merge: 18159

# %%
# rename columns name

df_final.rename(columns={'Country_Desc': 'Market'}, inplace=True)
df_final.rename(columns={'SMART_SEGMENTATION': 'pf_segmentation'}, inplace=True)
df_final.rename(columns={'MCO_SEGMENTATION': 'market_segmentation'}, inplace=True)
df_final.rename(columns={'STRATEGY_SEGMENTATION': 'gmid_segmentation'}, inplace=True)
df_final.rename(columns={'Coverage': 'coverage_months'}, inplace=True)
                         
# Define the new order of columns
new_order = ['Date', 'PRODUCT_FAMILY', 'GMID', 'LOC', 'Country','Market', 'Geography', 'Sales','Forecast', 'MAPE',
             'Absolute Error','coverage_months', 'Min', 'Max', 'market_segmentation', 'pf_segmentation',	'gmid_segmentation']

# Apply the new order
df = df_final[new_order]
df.head()
# Out:
#         Date  PRODUCT_FAMILY    GMID    LOC Country Market      Geography  \
# 0 2023-07-01               6  600001  KR001      KR  Korea  International
# 1 2023-08-01               6  600001  KR001      KR  Korea  International
# 2 2023-09-01               6  600001  KR001      KR  Korea  International
# 3 2023-10-01               6  600001  KR001      KR  Korea  International
# 4 2023-11-01               6  600001  KR001      KR  Korea  International
#
#   Sales    Forecast    MAPE  Absolute Error  coverage_months   Min   Max  \
# 0   909  868.279179   4.50%       40.720821             1.82  2.73  4.91
# 1   786  867.675973  10.40%       81.675973             4.27  2.73  4.91
# 2   846  906.330589   7.10%       60.330590             3.27  2.73  4.91
# 3   761  907.327425  19.20%      146.327425             2.27  2.73  4.91
# 4   786  868.000000  10.40%       82.000000             3.23  2.73  4.91
#
#   market_segmentation pf_segmentation gmid_segmentation
# 0           Major MCO          Secure          Platinum
# 1           Major MCO          Secure          Platinum
# 2           Major MCO          Secure          Platinum
# 3           Major MCO          Secure          Platinum
# 4           Major MCO          Secure          Platinum

# %% [markdown]
# # Data Cleaning & Wrangling

# %%
#format the headers
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')

# %%
#check data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18159 entries, 0 to 18158
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 18159 non-null  datetime64[ns]
#  1   product_family       18159 non-null  int64
#  2   gmid                 18159 non-null  int64
#  3   loc                  18159 non-null  object
#  4   country              18159 non-null  object
#  5   market               18159 non-null  object
#  6   geography            18159 non-null  object
#  7   sales                18159 non-null  object
#  8   forecast             18159 non-null  float64
#  9   mape                 16404 non-null  object
#  10  absolute_error       18159 non-null  float64
#  11  coverage_months      16533 non-null  float64
#  12  min                  16533 non-null  float64
#  13  max                  16533 non-null  float64
#  14  market_segmentation  18159 non-null  object
#  15  pf_segmentation      18159 non-null  object
#  16  gmid_segmentation    18159 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(9)
# memory usage: 2.4+ MB

# %%
#change types by column

# Remove commas and convert to integers
df['sales'] = df['sales'].astype(str).str.replace(',', '', regex=False)
df['sales'] = pd.to_numeric(df['sales'], errors='coerce').fillna(0).astype('int64')

df['forecast'] = (
    df['forecast']
    .astype(str)
    .str.replace(',', '', regex=False)
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
    .apply(lambda x: int(round(x)))
)


float_cols = ['mape','absolute_error','coverage_months', 'min', 'max']

for col in float_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').round(2)

df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
#recalculate MAPE, Absolute error columns

# Absolute errors
df['absolute_error'] = (df['forecast'].astype(float) - df['sales'].astype(float)).abs().round(2)

# Recalculate mape 
df['mape'] = df.apply(
    lambda row: round(abs(row['sales'] - row['forecast']) / row['sales'] * 100, 2)
    if row['sales'] != 0 else 0,
    axis=1
)

# %%
df.head()
# Out:
#         date  product_family    gmid    loc country market      geography  \
# 0 2023-07-01               6  600001  KR001      KR  Korea  International
# 1 2023-08-01               6  600001  KR001      KR  Korea  International
# 2 2023-09-01               6  600001  KR001      KR  Korea  International
# 3 2023-10-01               6  600001  KR001      KR  Korea  International
# 4 2023-11-01               6  600001  KR001      KR  Korea  International
#
#    sales  forecast   mape  absolute_error  coverage_months   min   max  \
# 0    909       868   4.51            41.0             1.82  2.73  4.91
# 1    786       868  10.43            82.0             4.27  2.73  4.91
# 2    846       906   7.09            60.0             3.27  2.73  4.91
# 3    761       907  19.19           146.0             2.27  2.73  4.91
# 4    786       868  10.43            82.0             3.23  2.73  4.91
#
#   market_segmentation pf_segmentation gmid_segmentation  year  month
# 0           Major MCO          Secure          Platinum  2023      7
# 1           Major MCO          Secure          Platinum  2023      8
# 2           Major MCO          Secure          Platinum  2023      9
# 3           Major MCO          Secure          Platinum  2023     10
# 4           Major MCO          Secure          Platinum  2023     11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18159 entries, 0 to 18158
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 18159 non-null  datetime64[ns]
#  1   product_family       18159 non-null  int64
#  2   gmid                 18159 non-null  int64
#  3   loc                  18159 non-null  object
#  4   country              18159 non-null  object
#  5   market               18159 non-null  object
#  6   geography            18159 non-null  object
#  7   sales                18159 non-null  int64
#  8   forecast             18159 non-null  int64
#  9   mape                 18159 non-null  float64
#  10  absolute_error       18159 non-null  float64
#  11  coverage_months      16533 non-null  float64
#  12  min                  16533 non-null  float64
#  13  max                  16533 non-null  float64
#  14  market_segmentation  18159 non-null  object
#  15  pf_segmentation      18159 non-null  object
#  16  gmid_segmentation    18159 non-null  object
#  17  year                 18159 non-null  int32
#  18  month                18159 non-null  int32
# dtypes: datetime64[ns](1), float64(5), int32(2), int64(4), object(7)
# memory usage: 2.5+ MB

# %%
df.shape
# Out:
# (18159, 19)

# %%
#Count of missing values per column
df.isna().sum()
# Out:
# date                      0
# product_family            0
# gmid                      0
# loc                       0
# country                   0
# market                    0
# geography                 0
# sales                     0
# forecast                  0
# mape                      0
# absolute_error            0
# coverage_months        1626
# min                    1626
# max                    1626
# market_segmentation       0
# pf_segmentation           0
# gmid_segmentation         0
# year                      0
# month                     0
# dtype: int64

# %%
# replace nan values
df[['coverage_months', 'min', 'max']] = df[['coverage_months', 'min', 'max']].fillna(0).round(2)

# %%
df.isna().sum()
# Out:
# date                   0
# product_family         0
# gmid                   0
# loc                    0
# country                0
# market                 0
# geography              0
# sales                  0
# forecast               0
# mape                   0
# absolute_error         0
# coverage_months        0
# min                    0
# max                    0
# market_segmentation    0
# pf_segmentation        0
# gmid_segmentation      0
# year                   0
# month                  0
# dtype: int64

# %%
#check gmid_key duplicates
df['gmid_key'] = df['gmid'].astype(str) + '_'+ df['year'].astype(str) + df['month'].astype(str) + '_'+ df['country'].astype(str)
duplicate_rows = df['gmid_key'].duplicated().sum()
duplicate_rows
# Out:
# 444

# %%
df[df['gmid_key'].duplicated()]
# Out:
#             date  product_family    gmid    loc country  market    geography  \
# 573   2023-07-01               3  300004  FR003      FR  France  Key Markets
# 574   2023-08-01               3  300004  FR003      FR  France  Key Markets
# 575   2023-09-01               3  300004  FR003      FR  France  Key Markets
# 576   2023-10-01               3  300004  FR003      FR  France  Key Markets
# 577   2023-11-01               3  300004  FR003      FR  France  Key Markets
# ...          ...             ...     ...    ...     ...     ...          ...
# 17992 2025-05-01              11  110047  FR003      FR  France  Key Markets
# 17994 2025-05-01              11  110048  FR003      FR  France  Key Markets
# 18018 2025-05-01              12  120017  FR003      FR  France  Key Markets
# 18116 2025-05-01              16  160019  FR003      FR  France  Key Markets
# 18118 2025-05-01              16  160020  FR003      FR  France  Key Markets
#
#        sales  forecast    mape  absolute_error  coverage_months   min   max  \
# 573       32        12   62.50            20.0             8.91  0.00  0.00
# 574        0        12    0.00            12.0             7.77  0.00  0.00
# 575        0        12    0.00            12.0             5.59  0.00  0.00
# 576        0        12    0.00            12.0             4.32  0.00  0.00
# 577       35        12   65.71            23.0             8.45  0.00  0.00
# ...      ...       ...     ...             ...              ...   ...   ...
# 17992      0         0    0.00             0.0             2.77  2.73  4.55
# 17994      4         0  100.00             4.0             0.32  2.73  4.55
# 18018     46         0  100.00            46.0             0.00  2.73  4.55
# 18116     45        43    4.44             2.0             4.86  2.73  5.45
# 18118     94        54   42.55            40.0             2.77  2.73  5.45
#
#       market_segmentation pf_segmentation gmid_segmentation  year  month  \
# 573               Top MCO          Secure          Platinum  2023      7
# 574               Top MCO          Secure          Platinum  2023      8
# 575               Top MCO          Secure          Platinum  2023      9
# 576               Top MCO          Secure          Platinum  2023     10
# 577               Top MCO          Secure          Platinum  2023     11
# ...                   ...             ...               ...   ...    ...
# 17992             Top MCO          Secure          Platinum  2025      5
# 17994             Top MCO          Secure          Platinum  2025      5
# 18018             Top MCO   Supply Growth          Platinum  2025      5
# 18116             Top MCO   Supply Growth          Platinum  2025      5
# 18118             Top MCO   Supply Growth          Platinum  2025      5
#
#                gmid_key
# 573     300004_20237_FR
# 574     300004_20238_FR
# 575     300004_20239_FR
# 576    300004_202310_FR
# 577    300004_202311_FR
# ...                 ...
# 17992   110047_20255_FR
# 17994   110048_20255_FR
# 18018   120017_20255_FR
# 18116   160019_20255_FR
# 18118   160020_20255_FR
#
# [444 rows x 20 columns]

# %%
#Handle duplicated gmid_key rows by summing sales and forecast, while keeping the first values for the rest, 
#The difference is in loc and the country is the same (FR001 and FR003; Ae001 and AE002, SG001 and SG002)

agg_dict = {
    'sales': 'sum',
    'forecast': 'sum',
    'date': 'first',
    'gmid': 'first',
    'country': 'first',
    'product_family': 'first',
    'market': 'first',
    'geography': 'first',
    'mape': 'first',
    'absolute_error': 'first',
    'coverage_months': 'first',
    'min': 'first',
    'max': 'first',
    'market_segmentation': 'first', 
    'pf_segmentation': 'first',
    'gmid_segmentation': 'first',
    'year': 'first',
    'month': 'first'
}
df_grouped = df.groupby('gmid_key', as_index=False).agg(agg_dict)

# %%
#check duplicates
df_grouped['gmid_key'].duplicated().sum()
# Out:
# 0

# %%
# Define the new order of columns
new_order = ['gmid_key','date','year', 'month','product_family', 'gmid', 'country','market', 'geography', 'sales','forecast', 'mape',
             'absolute_error','coverage_months', 'min', 'max', 'market_segmentation', 'pf_segmentation', 'gmid_segmentation']

# Apply the new order
df_all = df_grouped[new_order]

# %%
#recalculate MAPE and Absolute error columns

# Absolute errors
df_all['absolute_error'] = (df_all['forecast'].astype(float) - df_all['sales'].astype(float)).abs().round(2)

# Recalculate mape 
df_all['mape'] = df_all.apply(
    lambda row: round(abs(row['sales'] - row['forecast']) / row['sales'] * 100, 2)
    if row['sales'] != 0 else 0,
    axis=1
)

# %%
df_all.head()
# Out:
#            gmid_key       date  year  month  product_family    gmid country  \
# 0  100001_202310_AU 2023-10-01  2023     10               1  100001      AU
# 1  100001_202310_NZ 2023-10-01  2023     10               1  100001      NZ
# 2  100001_202311_AU 2023-11-01  2023     11               1  100001      AU
# 3  100001_202311_NZ 2023-11-01  2023     11               1  100001      NZ
# 4  100001_202312_AU 2023-12-01  2023     12               1  100001      AU
#
#         market      geography  sales  forecast    mape  absolute_error  \
# 0    Australia  International     93       108   16.13            15.0
# 1  New Zealand  International     26        23   11.54             3.0
# 2    Australia  International    158        87   44.94            71.0
# 3  New Zealand  International      3        23  666.67            20.0
# 4    Australia  International     69        88   27.54            19.0
#
#    coverage_months   min   max market_segmentation pf_segmentation  \
# 0            10.68  2.73  5.45         Regular MCO          Secure
# 1             3.55  2.73  4.09         Regular MCO          Secure
# 2             9.59  2.73  5.45         Regular MCO          Secure
# 3             3.36  2.73  4.09         Regular MCO          Secure
# 4             8.45  2.73  5.45         Regular MCO          Secure
#
#   gmid_segmentation
# 0      Auto Piloted
# 1      Auto Piloted
# 2      Auto Piloted
# 3      Auto Piloted
# 4      Auto Piloted

# %%
df_all.to_csv('file.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
#count of GMIDs
num_gmids = df_all['gmid'].nunique()
print(f"Total unique GMIDs: {num_gmids}")
# Out:
# Total unique GMIDs: 829

# %%
#count of Product Family
num_pf = df_all['product_family'].nunique()
print(f"Total unique Product Family: {num_pf}")
# Out:
# Total unique Product Family: 16

# %%
#count of Markets
num_markt = df_all['country'].nunique()
print(f"Total unique Market: {num_markt}")
# Out:
# Total unique Market: 71

# %%
#Check statistical summary
num_cols = ['sales', 'forecast', 'mape','absolute_error']

df_all[num_cols].describe()
# Out:
#                sales      forecast           mape  absolute_error
# count   17715.000000   17715.00000   17715.000000    17715.000000
# mean     1635.347163    1669.63974      72.472098      314.643240
# std     12292.032688   12384.19767    1421.763107     1930.796361
# min         0.000000       0.00000       0.000000        0.000000
# 25%        28.000000      31.00000       6.215000       10.000000
# 50%       145.000000     148.00000      19.860000       39.000000
# 75%       650.000000     660.00000      51.145000      140.000000
# max    383242.000000  370680.00000  178150.000000    57901.000000

# %% [markdown]
# ### Univariate Analysis

# %%
#Check distribution for numerical features
metrics = ['sales', 'forecast', 'mape']

for metric in metrics:
    plt.figure(figsize=(12, 5))
    
    # Histogram 
    plt.subplot(1, 2, 1)
    sns.histplot(df_all[metric], bins=40, color='skyblue')
    plt.title(f'{metric} - Histogram')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df_all[metric], color='salmon')
    plt.title(f'{metric} - Boxplot')

    plt.tight_layout()
    plt.show()

# %%
#High Sales by Country
# Filter rows where sales > 75th percentile
filtered_df = df_all[df_all['sales'] > 650]

# Group by country
country_counts = filtered_df['country'].value_counts().reset_index()
country_counts.columns = ['country', 'count']

# Plot
plt.figure(figsize=(15, 5))
sns.barplot(data=country_counts, x='country', y='count', palette='viridis')
plt.title('Number of Records with Sales > 650 by Country')
plt.xlabel('Country')
plt.ylabel('Record Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1395921375.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=country_counts, x='country', y='count', palette='viridis')

# %%
#High Sales by Product Family

# Group by product_family
product_counts = filtered_df['product_family'].value_counts().reset_index()
product_counts.columns = ['product_family', 'count']

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(data=product_counts, x='product_family', y='count', palette='magma')
plt.title('Number of Records with Sales > 650 by Product Family')
plt.xlabel('Product Family')
plt.ylabel('Record Count')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1642206294.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=product_counts, x='product_family', y='count', palette='magma')

# %%
# Filter rows where MAPE > 75th percentile
high_mape_df = df_all[df_all['mape'] > 51.145]

# Count high MAPE records by country
country_mape_counts = high_mape_df['country'].value_counts().reset_index()
country_mape_counts.columns = ['country', 'count']

# Plot
plt.figure(figsize=(16, 5))
sns.barplot(data=country_mape_counts, x='country', y='count', palette='rocket')
plt.title('Records with MAPE > 75th Percentile by Country')
plt.xlabel('Country')
plt.ylabel('Record Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/914790075.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=country_mape_counts, x='country', y='count', palette='rocket')

# %%
# Filter rows where MAPE > 1000%
high_mape_df2 = df_all[df_all['mape'] > 1000]

# Count high MAPE records by country
country_mape_counts2 = high_mape_df2['country'].value_counts().reset_index()
country_mape_counts2.columns = ['country', 'count']

# Plot
plt.figure(figsize=(16, 5))
sns.barplot(data=country_mape_counts2, x='country', y='count', palette='rocket')
plt.title('Records with MAPE > 1000 by Country')
plt.xlabel('Country')
plt.ylabel('Record Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/292676926.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=country_mape_counts2, x='country', y='count', palette='rocket')

# %%
# Count the number of entries per country
country_counts = df_all['country'].value_counts().sort_values(ascending=True)

# Set the figure size for better spacing
plt.figure(figsize=(16, 8))  # Dynamically scale height

# Plot horizontal bar chart
sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")

# Beautify the chart
plt.title("Number of Records per Country", fontsize=16)
plt.xlabel("Count", fontsize=12)
plt.ylabel("Country", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/849339730.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")

# %% [markdown]
# ### Bivariate Analysis

# %%
#mean (average) of sales for each month
sns.barplot(x="month", y="sales", data=df_all, ci=None)
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/3316875510.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="month", y="sales", data=df_all, ci=None)
# <Axes: xlabel='month', ylabel='sales'>

# %%
df_all.set_index('date').resample('M')['sales'].sum().plot(title='Monthly Sales Trend')
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1792484267.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_all.set_index('date').resample('M')['sales'].sum().plot(title='Monthly Sales Trend')
# <Axes: title={'center': 'Monthly Sales Trend'}, xlabel='date'>

# %% [markdown]
# * Despite the upward trend, there are visible dips along the way, suggesting seasonal effects, market shifts, or temporary challenges.

# %%
#Sales Vs Forecast
sns.scatterplot(x='forecast', y='sales', data=df_all)
plt.title('Forecast vs. Sales')
# Out:
# Text(0.5, 1.0, 'Forecast vs. Sales')

# %% [markdown]
# * Strong Positive Correlation: Sales values rise alongside forecast values. This tight clustering along a diagonal suggests a reliable prediction model—when forecasts go up, actual sales usually follow.
#
# * Forecast Accuracy: The proximity of most data points to the diagonal implies high accuracy in predictions. Few outliers indicate minimal deviation between forecasted and actual results.
#
# * Strategic Alignment: The consistent relationship means business strategies based on forecasts are likely well-aligned with market performance.

# %%
#sales vs. forecast side by side for each product family
# Group and sum sales & forecast by product family
sales_forecast_pf = df_all.groupby('product_family')[['sales', 'forecast']].sum().reset_index()
# Melt data to long format for grouped bars
melted_pf = sales_forecast_pf.melt(
    id_vars='product_family',
    value_vars=['sales', 'forecast'],
    var_name='type',
    value_name='value'
)



plt.figure(figsize=(12, 6))
ax = sns.barplot(data=melted_pf, x='product_family', y='value', hue='type', palette='Set2')

# Use logarithmic scale for y-axis
ax.set_yscale('log')




plt.title('Sales vs. Forecast by Product Family (Log Scale)')
plt.xlabel('Product Family')
plt.ylabel('Total Units (log scale)')
plt.legend(title='Metric')
plt.tight_layout()
plt.show()

# %%
# Group and calculate average MAPE by product family
mape_by_pf = df_all.groupby('product_family')['mape'].mean().reset_index()

# Sort by MAPE if needed (optional)
mape_by_pf = mape_by_pf.sort_values(by='mape', ascending=False)

# Plot
plt.figure(figsize=(12, 5))
ax = sns.barplot(data=mape_by_pf, x='product_family', y='mape', palette='Blues_r')

# Add value labels
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')

plt.title('Average MAPE by Product Family')
plt.xlabel('Product Family')
plt.ylabel('Average MAPE (%)')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/3138713924.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=mape_by_pf, x='product_family', y='mape', palette='Blues_r')

# %%
# Sum total sales per country
sales_by_country = df_all.groupby("country", as_index=False)["sales"].sum()
sales_by_country = sales_by_country.sort_values(by="sales", ascending=False)

# Plot total sales
plt.figure(figsize=(16, 8))
sns.barplot(x="country", y="sales", data=sales_by_country)
plt.title("Total Sales by Country in volume", fontsize=16)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#mape across Countries

# First, extract the sorted country order based on total sales
country_order = sales_by_country['country']

# Now use that order in your MAPE boxplot
plt.figure(figsize=(16, 6))
sns.boxplot(x='country', y='mape', data=df_all, order=country_order)
plt.title("MAPE by Country", fontsize=16)
plt.xlabel("Country", fontsize=12)
plt.ylabel("MAPE", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Group by year and month to calculate average MAPE
mape_monthly_yearly = (
    df_all.groupby(['year', 'month'])['mape']
    .mean()
    .reset_index()
)

# Optional: create a datetime column for plotting
mape_monthly_yearly['date'] = pd.to_datetime(
    mape_monthly_yearly[['year', 'month']].assign(day=1)
)


plt.figure(figsize=(14, 6))
sns.lineplot(data=mape_monthly_yearly, x='date', y='mape', marker='o', color='darkgreen')

plt.title('Average MAPE Evolution Across Months and Years')
plt.xlabel('Date')
plt.ylabel('Average MAPE (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Diagnose the June 2024 Spike

# %%
spike_df = df_all[(df_all['year'] == 2024) & (df_all['month'] == 6)]
spike_summary = spike_df.groupby(['country', 'product_family'])['mape'].mean().reset_index().sort_values(by='mape', ascending=False)

spike_summary
# Out:
#     country  product_family        mape
# 129      DZ               8  178150.000
# 241      IT              13    2261.455
# 188      GT               8    2249.400
# 136      EG              13    1076.470
# 132      EC              17     600.000
# ..      ...             ...         ...
# 386      TR              11       0.000
# 387      TR              15       0.000
# 92       CY               3       0.000
# 275      MA              11       0.000
# 98       CZ               7       0.000
#
# [426 rows x 3 columns]

# %%
geo_mape = df_all.groupby(['geography', 'year', 'month'])['mape'].mean().reset_index()

geo_mape
# Out:
#         geography  year  month       mape
# 0   Greater China  2023      7  90.121842
# 1   Greater China  2023      8  32.867222
# 2   Greater China  2023      9  41.278649
# 3   Greater China  2023     10  34.737368
# 4   Greater China  2023     11  27.195263
# ..            ...   ...    ...        ...
# 87  North America  2025      1  21.976463
# 88  North America  2025      2  31.008072
# 89  North America  2025      3  26.544000
# 90  North America  2025      4  26.443494
# 91  North America  2025      5  27.801220
#
# [92 rows x 4 columns]

# %%
# Create a datetime column for proper x-axis formatting
geo_mape['date'] = pd.to_datetime(geo_mape[['year', 'month']].assign(day=1))

plt.figure(figsize=(14, 6))
sns.lineplot(data=geo_mape, x='date', y='mape', hue='geography', marker='o', palette='Set1')

plt.title('Average MAPE over Time by Geography')
plt.xlabel('Date')
plt.ylabel('Average MAPE (%)')
plt.legend(title='Geography', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_all[['mape', 'coverage_months', 'sales', 'absolute_error']].corr()
# Out:
#                      mape  coverage_months     sales  absolute_error
# mape             1.000000        -0.005169 -0.005154        0.018513
# coverage_months -0.005169         1.000000 -0.044754       -0.052242
# sales           -0.005154        -0.044754  1.000000        0.703657
# absolute_error   0.018513        -0.052242  0.703657        1.000000

# %%
# Set a larger figure size
plt.figure(figsize=(10, 6))  # Adjust width and height as needed

# Create the scatterplot
sns.scatterplot(data=df_all, x='sales', y='absolute_error', hue='geography')

# Move the legend to the right
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Apply tight layout to prevent clipping
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Key Observations
#
# Sales vs. Error Relationship
# * There's a weak positive trend—higher sales don’t necessarily correspond to lower absolute errors.
# * Some high-sales regions still show notable prediction errors.
#
# Regional Patterns
# * North America (orange) shows a wide spread in absolute error, indicating inconsistency in model performance.
# * Greater China (red) tends to cluster toward lower sales and lower errors—potentially a more stable segment.
# * International (blue) and Key Markets (green) span a wide range, but International seems to show less error at lower sales levels.

# %%
# Group by year and month to calculate average MAPE
monthly_mape = (
    df_all.groupby(['year', 'month'])['mape']
    .mean()
    .reset_index()
    .sort_values(by='mape', ascending=False)
)

# Display top months
top_mape_months = monthly_mape.head(10)
print(top_mape_months)
# Out:
#     year  month        mape
# 11  2024      6  285.479086
# 12  2024      7   94.973997
# 13  2024      8   92.077920
# 14  2024      9   91.715490
# 15  2024     10   84.113439
# 0   2023      7   72.862072
# 1   2023      8   72.823581
# 8   2024      3   61.528190
# 22  2025      5   61.045119
# 4   2023     11   59.984067

# %%
# Top 10 months by average MAPE
plt.figure(figsize=(10, 5))
monthly_top = top_mape_months.copy()
monthly_top['label'] = monthly_top['year'].astype(str) + '-' + monthly_top['month'].astype(str).str.zfill(2)

sns.barplot(data=monthly_top, x='label', y='mape', palette='Reds_r')
plt.title('Months with Highest Average MAPE')
plt.xlabel('Month')
plt.ylabel('MAPE (%)')
for container in plt.gca().containers:
    plt.gca().bar_label(container, fmt='%.2f')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1210487264.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_top, x='label', y='mape', palette='Reds_r')

# %%
# Group by country and calculate average MAPE
country_mape = (
    df_all.groupby('country')['mape']
    .mean()
    .reset_index()
    .sort_values(by='mape', ascending=False)
)

# Display top 5 countries
top_5_countries = country_mape.head(5)
print(top_5_countries)
# Out:
#    country         mape
# 18      DZ  2882.964127
# 26      GT   285.982895
# 19      EC   265.963600
# 69      VN   259.825652
# 20      EG   259.152526

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=top_5_countries, x='country', y='mape', palette='Oranges_r')
plt.title('Top 5 Countries with Highest Average MAPE')
plt.xlabel('Country')
plt.ylabel('MAPE (%)')
for container in plt.gca().containers:
    plt.gca().bar_label(container, fmt='%.2f')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1946291472.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_countries, x='country', y='mape', palette='Oranges_r')

# %%
# Group by product family and calculate MAPE standard deviation
pf_erratic = (
    df_all.groupby('product_family')['mape']
    .std()
    .reset_index()
    .rename(columns={'mape': 'mape_std'})
    .sort_values(by='mape_std', ascending=False)
)

# Display top erratic product families
top_erratic_pf = pf_erratic.head(10)
print(top_erratic_pf)
# Out:
#     product_family     mape_std
# 7                8  5129.588736
# 5                6  1091.563559
# 10              12   771.244945
# 13              15   392.178553
# 11              13   318.811152
# 14              16   312.200641
# 15              17   287.653657
# 12              14   271.606169
# 0                1   193.139316
# 9               11   182.451389

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data=top_erratic_pf, x='product_family', y='mape_std', palette='Purples')
plt.title('Product Families with Most Erratic Forecasts (MAPE Std Dev)')
plt.xlabel('Product Family')
plt.ylabel('MAPE Std Dev')
for container in plt.gca().containers:
    plt.gca().bar_label(container, fmt='%.2f')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/852693064.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_erratic_pf, x='product_family', y='mape_std', palette='Purples')

# %%
# Calculate average MAPE by country and sort descending
data = (
    df_all.groupby('country')['mape']
    .mean()
    .reset_index()
    .sort_values(by='mape', ascending=False)
)

# Plot bar chart
plt.figure(figsize=(16, 6))
ax = sns.barplot(data=data, x='country', y='mape', palette='viridis')

# Add value labels to bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge')

plt.title('Average MAPE by Country (Descending Order)')
plt.xlabel('Country')
plt.ylabel('MAPE (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/2813710565.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=data, x='country', y='mape', palette='viridis')

# %%
#mape across Product Families

plt.figure(figsize=(14, 6))  # You can adjust width and height as needed
sns.boxplot(x='product_family', y='mape', data=df_all)
plt.title("MAPE Across Product Families", fontsize=16)
plt.xlabel("Product Family", fontsize=12)
plt.ylabel("MAPE", fontsize=12)
plt.xticks(rotation=0)  # Rotating labels often helps with wider plots
plt.tight_layout()
plt.show()

# %%
#mape by Geography

plt.figure(figsize=(14, 6))  # You can adjust width and height as needed
sns.boxplot(x='geography', y='mape', data=df_all)
plt.title("MAPE By Geography", fontsize=16)
plt.xlabel("Geography", fontsize=12)
plt.ylabel("MAPE", fontsize=12)
plt.xticks(rotation=0)  # Rotating labels often helps with wider plots
plt.tight_layout()
plt.show()

# %%
#Correlation Heatmap
correlation = df_all[['year','month','product_family','gmid','sales', 'forecast', 'mape', 'absolute_error']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
def count_outliers_iqr(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return ((series < lower) | (series > upper)).sum()

# Columns to analyze
cols_to_check = ['sales', 'forecast', 'mape']
outlier_counts = {col: count_outliers_iqr(df_all[col].dropna()) for col in cols_to_check}

# Display
pd.Series(outlier_counts, name='Outlier Count')
# Out:
# sales       2208
# forecast    2214
# mape        1100
# Name: Outlier Count, dtype: int64

# %% [markdown]
# * sales - around 12% - Moderate; could cap or transform.
# * forecast - around 12% - Similar to sales; likely due to erratic predictions.
# * mape - around 6% - Many MAPE outliers reflect high error (often from small sales).

# %% [markdown]
# ### Log transformation and segmentation

# %%
#consider only sales >0

df_active = df_all[df_all['sales'] > 0].copy()


# Log transformation and segmentation
df_active['log_sales'] = np.log1p(df_active['sales']) 
df_active['log_segment'] = pd.cut(df_active['log_sales'], 
                                 bins=[-np.inf, 2, 4, 6, np.inf], 
                                 labels=['Very Low', 'Low-Mid', 'Mid-High', 'Very-High'])

# Plotting both segmentation strategies side-by-side
plt.figure(figsize=(14, 6))

# Log-based plot
plt.subplot(1, 2, 2)
sns.countplot(x='log_segment', data=df_active, palette='summer')
plt.title('Sales Segmentation by Log Scale')
plt.xlabel('Segment')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/731797068.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='log_segment', data=df_active, palette='summer')

# %%
# Plot original vs log-transformed sales
plt.figure(figsize=(14, 6))

# Original sales distribution
plt.subplot(1, 2, 1)
sns.histplot(df_all['sales'], bins=50, kde=True, color='skyblue')
plt.title('Original Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')

# Log-transformed sales distribution
plt.subplot(1, 2, 2)
sns.histplot(df_active['log_sales'], bins=50, kde=True, color='lightgreen')
plt.title('Log-Transformed Sales Distribution')
plt.xlabel('Log(Sales + 1)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Ensure 'log_segment' exists and is correctly ordered
segment_order = ['Very Low', 'Low-Mid', 'Mid-High', 'Very-High']

# Calculate average MAPE by log segment (using df_active)
mape_by_segment = df_active.groupby('log_segment')['mape'].mean().reindex(segment_order)

# Create the plot
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df_active, x='log_segment', order=segment_order, palette='viridis')

# Annotate each bar with count and MAPE
for p, segment_name in zip(ax.patches, segment_order):
    height = p.get_height()
    xpos = p.get_x() + p.get_width() / 2.

    # Add count label above the bar
    ax.text(xpos, height + 50, f'{int(height)}', ha='center', fontsize=11, fontweight='bold')

    # Add MAPE label inside the bar
    mape_val = mape_by_segment.get(segment_name, np.nan)
    ax.text(xpos, height / 2, f'MAPE: {mape_val:.1f}%', ha='center', va='center',
            fontsize=10, color='white', fontweight='bold')

# Formatting
plt.title("Active Product Count by Log-Based Segment with Average MAPE")
plt.xlabel("Log-Based Sales Segment")
plt.ylabel("Count of Records")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1198648650.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mape_by_segment = df_active.groupby('log_segment')['mape'].mean().reindex(segment_order)
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1198648650.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df_active, x='log_segment', order=segment_order, palette='viridis')

# %% [markdown]
# * High volume products have the lowest average MAPE —  forecasts are relatively more accurate.
# * Low volume products have a higher MAPE — forecasts are less accurate.

# %% [markdown]
# **** train separate models or tune differently for each segment

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_active, x='log_segment', y='mape')
plt.title('MAPE Distribution by Log Segment')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_active, x='pf_segmentation', y='mape', palette='Set3')
plt.title('MAPE Distribution by Product Family Segmentation')
plt.xlabel('PF Segmentation')
plt.ylabel('MAPE (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1449197908.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_active, x='pf_segmentation', y='mape', palette='Set3')

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df_active, x='market_segmentation', y='mape', palette='Pastel1')
plt.title('MAPE Distribution by Market Segmentation')
plt.xlabel('Market Segmentation')
plt.ylabel('MAPE (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1005990781.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_active, x='market_segmentation', y='mape', palette='Pastel1')

# %%
# Encode segmentation columns
encoded_df = df_active.copy()
segmentation_cols = ['market_segmentation', 'pf_segmentation', 'gmid_segmentation', 'log_segment']
encoded_df[segmentation_cols] = encoded_df[segmentation_cols].astype('category').apply(lambda x: x.cat.codes)

correlation_matrix = encoded_df[['mape'] + segmentation_cols].corr()
correlation_matrix['mape']
# Out:
# mape                   1.000000
# market_segmentation   -0.022587
# pf_segmentation       -0.006669
# gmid_segmentation     -0.006499
# log_segment           -0.061894
# Name: mape, dtype: float64

# %%
heatmap_df = (
    df_all.groupby(['pf_segmentation', 'market_segmentation'])['mape']
    .mean()
    .unstack()
)

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_df, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Average MAPE by PF & Market Segmentation')
plt.xlabel('Market Segmentation')
plt.ylabel('PF Segmentation')
plt.tight_layout()
plt.show()

# %% [markdown]
# PF Segmentation	Market Segmentation	Avg MAPE (%)	Insight
# Secure	Regular MCO	129.29	🚨 Highest error — this intersection struggles most
# Secure	Major MCO	79.67	Moderate error, but still notable
# Secure	Top MCO	43.62	🔹 Best performance in the Secure group
# Supply Growth	Major MCO	116.71	🚨 Very high — worth deeper review
# Supply Growth	Regular MCO	83.62	Moderate volatility
# Supply Growth	Top MCO	37.59	🟢 Strongest forecast accuracy overall

# %% [markdown]
# What You Can Do With This
# 1️⃣ Targeted Model Calibration
# Segment your ML pipeline based on these intersections. For example:
#
# Use different hyperparameters or ensemble strategies for Secure + Regular MCO
#
# Isolate Supply Growth + Top MCO as a benchmark or stability zone
#
# 2️⃣ Feature Engineering
# Include these combined segmentations (e.g. Secure_Regular_MCO) as categorical features in your predictive model. That way, model training accounts for historical error volatility per cluster.
#
# 3️⃣ Anomaly Buffering
# For high-MAPE cells like Secure + Regular MCO, consider:
#
# Looser prediction intervals
#
# Conservative forecasting methods
#
# Override rules during promotional cycles or volatile months

# %% [markdown]
# Strategic Implications
# Regular MCO + Secure is a red flag. It may need separate handling in forecasting: capped errors, exception rules, even exclusion from some training data.
#
# Supply Growth + Top MCO behaves well—this could serve as a model calibration baseline or be trusted with more aggressive forecasting.
#
# You might consider:
#
# Segmenting models by seg_combo
#
# Flagging volatile clusters for anomaly detection
#
# Designing smarter fallback logic for the worst-performing segments

# %%
#Combine segmentation columns into hybrid features
df_active['seg_combo'] = df_all['pf_segmentation'] + '_' + df_all['market_segmentation']

# %%
# Create lag features
df_active = df_active.sort_values(by=['gmid', 'year', 'month'])
df_active['sales_lag_3'] = df_active.groupby('gmid')['sales'].shift(3)
df_active['forecast_lag_3'] = df_active.groupby('gmid')['forecast'].shift(3)

df_active['sales_lag_3'] = df_active['sales_lag_3'].fillna(0)
df_active['forecast_lag_3'] = df_active['forecast_lag_3'].fillna(0)

# %%
df_active.head()
# Out:
#            gmid_key       date  year  month  product_family    gmid country  \
# 6   100001_20237_AU 2023-07-01  2023      7               1  100001      AU
# 7   100001_20237_NZ 2023-07-01  2023      7               1  100001      NZ
# 8   100001_20238_AU 2023-08-01  2023      8               1  100001      AU
# 9   100001_20238_NZ 2023-08-01  2023      8               1  100001      NZ
# 10  100001_20239_AU 2023-09-01  2023      9               1  100001      AU
#
#          market      geography  sales  ...   min   max  market_segmentation  \
# 6     Australia  International     75  ...  2.73  5.45          Regular MCO
# 7   New Zealand  International     29  ...  2.73  4.09          Regular MCO
# 8     Australia  International     66  ...  2.73  5.45          Regular MCO
# 9   New Zealand  International     26  ...  2.73  4.09          Regular MCO
# 10    Australia  International     48  ...  2.73  5.45          Regular MCO
#
#     pf_segmentation  gmid_segmentation  log_sales log_segment  \
# 6            Secure       Auto Piloted   4.330733    Mid-High
# 7            Secure       Auto Piloted   3.401197     Low-Mid
# 8            Secure       Auto Piloted   4.204693    Mid-High
# 9            Secure       Auto Piloted   3.295837     Low-Mid
# 10           Secure       Auto Piloted   3.891820     Low-Mid
#
#              seg_combo sales_lag_3  forecast_lag_3
# 6   Secure_Regular MCO         0.0             0.0
# 7   Secure_Regular MCO         0.0             0.0
# 8   Secure_Regular MCO         0.0             0.0
# 9   Secure_Regular MCO        75.0           102.0
# 10  Secure_Regular MCO        29.0            36.0
#
# [5 rows x 24 columns]

# %%
df_active.to_csv('file_before_ml.csv', index=False)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ### Train Test Split

# %%
features = ['sales_lag_3', 'forecast_lag_3', 'log_sales', 'pf_segmentation', 'market_segmentation']
X = pd.get_dummies(df_active[features])
y = df_active['sales']  # or forecast

# %%
X.head()
# Out:
#     sales_lag_3  forecast_lag_3  log_sales  pf_segmentation_Secure  \
# 6           0.0             0.0   4.330733                    True
# 7           0.0             0.0   3.401197                    True
# 8           0.0             0.0   4.204693                    True
# 9          75.0           102.0   3.295837                    True
# 10         29.0            36.0   3.891820                    True
#
#     pf_segmentation_Supply Growth  market_segmentation_Major MCO  \
# 6                           False                          False
# 7                           False                          False
# 8                           False                          False
# 9                           False                          False
# 10                          False                          False
#
#     market_segmentation_Regular MCO  market_segmentation_Top MCO
# 6                              True                        False
# 7                              True                        False
# 8                              True                        False
# 9                              True                        False
# 10                             True                        False

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %% [markdown]
# ### Scalling

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)
X_train_scaled.head()
# Out:
#    sales_lag_3  forecast_lag_3  log_sales  pf_segmentation_Secure  \
# 0    -0.127457       -0.129095  -1.777363                0.777277
# 1    -0.090359       -0.089251   0.440405                0.777277
# 2    -0.118836       -0.118647   0.030990                0.777277
# 3    -0.126586       -0.130335  -1.046537                0.777277
# 4    -0.128241       -0.128564  -1.381413               -1.286543
#
#    pf_segmentation_Supply Growth  market_segmentation_Major MCO  \
# 0                      -0.777277                      -0.340858
# 1                      -0.777277                       2.933771
# 2                      -0.777277                      -0.340858
# 3                      -0.777277                      -0.340858
# 4                       1.286543                       2.933771
#
#    market_segmentation_Regular MCO  market_segmentation_Top MCO
# 0                        -0.701639                     0.875632
# 1                        -0.701639                    -1.142033
# 2                        -0.701639                     0.875632
# 3                         1.425235                    -1.142033
# 4                        -0.701639                    -1.142033

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns = X_test.columns)
X_test_scaled.head()
# Out:
#    sales_lag_3  forecast_lag_3  log_sales  pf_segmentation_Secure  \
# 0    -0.037498       -0.058970   0.837391               -1.286543
# 1    -0.117355       -0.115902  -0.793203               -1.286543
# 2    -0.126412       -0.117319  -0.642768                0.777277
# 3    -0.125280       -0.128121  -0.832116                0.777277
# 4    -0.089662       -0.095272   0.724411                0.777277
#
#    pf_segmentation_Supply Growth  market_segmentation_Major MCO  \
# 0                       1.286543                      -0.340858
# 1                       1.286543                      -0.340858
# 2                      -0.777277                      -0.340858
# 3                      -0.777277                       2.933771
# 4                      -0.777277                      -0.340858
#
#    market_segmentation_Regular MCO  market_segmentation_Top MCO
# 0                         1.425235                    -1.142033
# 1                        -0.701639                     0.875632
# 2                        -0.701639                     0.875632
# 3                        -0.701639                    -1.142033
# 4                        -0.701639                     0.875632

# %% [markdown]
# #### Linear regression

# %% [markdown]
# MAPE is scale-independent, making it great for comparisons across datasets with different units.
#
# RMSE might overemphasize large errors, which is useful if your project needs high accuracy on high-value predictions.
#
# MAE is more robust to outliers than RMSE and provides a straight average of error magnitude.

# %%
# Initialize the model
lin_reg = LinearRegression()

# Train the model
lin_reg.fit(X_train_scaled, y_train)

# Predict
pred_lin = lin_reg.predict(X_test_scaled)

# Evaluate performance
r2_lin = r2_score(y_test, pred_lin)
mae_lin = mean_absolute_error(y_test, pred_lin)
rmse_lin = root_mean_squared_error(y_test, pred_lin)
mape_lin = mean_absolute_percentage_error(y_test, pred_lin)


print(f"R² Score: {r2_lin:.3f}")
print(f"MAE: {mae_lin:.2f}")
print(f"RMSE: {rmse_lin:.2f}")
print(f"MAPE: {mape_lin:.2%}")
# Out:
# R² Score: 0.138
# MAE: 3523.41
# RMSE: 14451.32
# MAPE: 15054.58%

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, pred_lin, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')

plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales (Linear Regression)')
plt.title(f'Linear Regression Forecast\nR²: {r2_lin:.2f} | MAE: {mae_lin:.2f}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### KNN

# %%
# Train KNN model
knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train_scaled, y_train)

# Predict on test data
pred_knn = knn.predict(X_test_scaled)

# Evaluate
print("MAE", mean_absolute_error(pred_knn, y_test))
print("RMSE", root_mean_squared_error(pred_knn, y_test))
print("R2 score", knn.score(X_test_scaled, y_test))
print("MAPE", mean_absolute_percentage_error(pred_knn, y_test))
# Out:
# MAE 259.57156162682395
# RMSE 3443.757982780978
# R2 score 0.9510239623613584
# MAPE 0.01853718962461414

# %%
r2_knn = r2_score(y_test, pred_knn)
mae_knn = mean_absolute_error(y_test, pred_knn)


plt.figure(figsize=(8,6))
plt.scatter(y_test, pred_knn, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')

plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales (KNN)')
plt.title(f'Actual vs Predicted Values with KNN\nR²: {r2_knn:.2f} | MAE: {mae_knn:.2f}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### RandomForest

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=20)
rf_model.fit(X_train_scaled, y_train)
pred_rf = rf_model.predict(X_test_scaled)

print("MAE", mean_absolute_error(pred_rf, y_test))
print("RMSE", root_mean_squared_error(pred_rf, y_test))
print("R2 score", rf_model.score(X_test_scaled, y_test))
print("MAPE", mean_absolute_percentage_error(pred_rf, y_test))
# Out:
# MAE 39.166317913691415
# RMSE 926.0788242838686
# R2 score 0.9964582793169883
# MAPE 0.00038424360428964386

# %%
# Plot actual vs predicted

r2 = r2_score(y_test, pred_rf)
mae = mean_absolute_error(y_test, pred_rf)

plt.figure(figsize=(8,6))
plt.scatter(y_test, pred_rf, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Perfect fit line

plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title(f'Actual vs Predicted (RandomForest)\nR²: {r2:.2f} | MAE: {mae:.2f}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Gradient Boosting

# %%
gb_reg = GradientBoostingRegressor(max_depth=6, n_estimators=100)
gb_reg.fit(X_train_scaled, y_train)

# Predict and evaluate
pred_gb = gb_reg.predict(X_test_scaled)
mae_pred_gb = mean_absolute_error(y_test, pred_gb)
rmse_pred_gb = root_mean_squared_error(y_test, pred_gb)
r2_pred_gb = gb_reg.score(X_test_scaled, y_test)
mape_pred_gb = mean_absolute_percentage_error(y_test, pred_gb)

print("MAE:", mae_pred_gb)
print("RMSE:", rmse_pred_gb)
print("R2 Score:", r2_pred_gb)
print("MAPE", mape_pred_gb)
# Out:
# MAE: 26.889939716674007
# RMSE: 537.4787670190577
# R2 Score: 0.9988069984041152
# MAPE 0.02422241389519826

# %%
# Plot actual vs predicted
plt.figure(figsize=(8,6))
plt.scatter(y_test, pred_gb, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Perfect fit line

plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title(f'Actual vs Predicted (Gradient Boosting)\nR²: {r2_pred_gb:.2f} | MAE: {mae_pred_gb:.2f}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### XGBoost

# %%
# Initialize XGBoost model
xgb_reg = xgb.XGBRegressor(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    objective='reg:squarederror',
    random_state=42
)

xgb_reg.fit(X_train, y_train)

# Evaluate
pred_xgb = xgb_reg.predict(X_test)


print("XGBoost MAE:", mean_absolute_error(y_test, pred_xgb))
print("XGBoost RMSE:", root_mean_squared_error(y_test, pred_xgb))
print("XGBoost R²:", r2_score(y_test, pred_xgb))
print("MAPE", mean_absolute_percentage_error(y_test, pred_xgb))
# Out:
# XGBoost MAE: 198.55472607747328
# XGBoost RMSE: 2505.1982384692046
# XGBoost R²: 0.9740819334983826
# MAPE 0.27931183132757964

# %% [markdown]
# #### AdaBoost Regressor

# %%
# Initialize AdaBoost
ada_reg = AdaBoostRegressor(n_estimators=100, learning_rate=0.5, random_state=42)

# Train
ada_reg.fit(X_train_scaled, y_train)

# Predict and Evaluate
pred_ada = ada_reg.predict(X_test_scaled)
print("AdaBoost MAE:", mean_absolute_error(y_test, pred_ada))
print("AdaBoost RMSE:", root_mean_squared_error(y_test, pred_ada))
print("AdaBoost R²:", r2_score(y_test, pred_ada))
print("MAPE", mean_absolute_percentage_error(y_test, pred_ada))
# Out:
# AdaBoost MAE: 994.9605759310942
# AdaBoost RMSE: 1482.4308093564932
# AdaBoost R²: 0.9909245688815306
# MAPE 32.348916645088465

# %%
# Plot actual vs predicted

r2_ada = r2_score(y_test, pred_ada)
mae_ada = mean_absolute_error(y_test, pred_ada)

plt.figure(figsize=(8,6))
plt.scatter(y_test, pred_ada, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Perfect fit line

plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title(f'Actual vs Predicted (AdaBoost)\nR²: {r2_ada:.2f} | MAE: {mae_ada:.2f}')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bagging Regressor

# %%
# Initialize Bagging
bag_reg = BaggingRegressor(n_estimators=100, random_state=42)

# Train
bag_reg.fit(X_train_scaled, y_train)

# Predict and Evaluate
pred_bag = bag_reg.predict(X_test_scaled)
print("Bagging MAE:", mean_absolute_error(y_test, pred_bag))
print("Bagging RMSE:", mean_squared_error(y_test, pred_bag, squared=False))
print("Bagging R²:", r2_score(y_test, pred_bag))
print("MAPE", mean_absolute_percentage_error(y_test, pred_bag))
# Out:
# Bagging MAE: 36.488509779571544
# Bagging RMSE: 875.947392532601
# Bagging R²: 0.9968313487038987
# MAPE 0.00036921761279487775
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Define models and predictions
model_names = ['Linear', 'KNN', 'Random Forest', 'Gradient Boosting','XGBoost', 'AdaBoost', 'Bagging']
models = [lin_reg, knn, rf_model, gb_reg, xgb_reg, ada_reg, bag_reg]

# Collect metrics dynamically
rmse_train = [
    root_mean_squared_error(y_train, model.predict(X_train if model == xgb_reg else X_train_scaled))
    for model in models
]
rmse_test = [
    root_mean_squared_error(y_test, model.predict(X_test if model == xgb_reg else X_test_scaled))
    for model in models
]
r2_train = [
    r2_score(y_train, model.predict(X_train if model == xgb_reg else X_train_scaled))
    for model in models
]

r2_test = [
    r2_score(y_test, model.predict(X_test if model == xgb_reg else X_test_scaled))
    for model in models
]



# Bar chart setup
x = np.arange(len(model_names))
width = 0.35

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# RMSE comparison
rects1 = ax1.bar(x - width/2, rmse_train, width, label='Train', color='mediumseagreen')
rects2 = ax1.bar(x + width/2, rmse_test,  width, label='Test',  color='cornflowerblue')
ax1.set_ylabel('RMSE')
ax1.set_title('Train vs Test RMSE by Model')
ax1.set_xticks(x)
ax1.set_xticklabels(model_names, rotation=45)
ax1.legend()

# R² comparison
rects3 = ax2.bar(x - width/2, r2_train, width, label='Train', color='salmon')
rects4 = ax2.bar(x + width/2, r2_test,  width, label='Test',  color='orange')
ax2.set_ylabel('R² Score')
ax2.set_title('Train vs Test R² by Model')
ax2.set_xticks(x)
ax2.set_xticklabels(model_names, rotation=45)
ax2.legend()

# Annotate bars with values
def annotate_bars(ax, rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}', xy=(rect.get_x() + rect.get_width()/2, height),
                    xytext=(0, 3), textcoords="offset points",
                    ha='center', va='bottom')

annotate_bars(ax1, rects1)
annotate_bars(ax1, rects2)
annotate_bars(ax2, rects3)
annotate_bars(ax2, rects4)

plt.tight_layout()
plt.show()

# %% [markdown]
# Gradient Boosting stands out as the most promising candidate for tuning:
# metric	Train	Test	Insight
# RMSE	4.97	749.44	Lowest test error — excellent generalization
# R² Score	1.00	1.00	Perfect fit — but worth validating for overfittingM
# the tiny train RMSE suggests it’s fitting the training data extremely well.
#
# The low test RMSE and perfect R² imply it’s generalizing better than other models.
#
# Compared to Random Forest and Bagging (which also show strong R²), Gradient Boosting has a much lower test RMSE, making it more efficient and precise.

# %% [markdown]
# That smaller difference between training and testing metrics in AdaBoost suggests it has better generalization and less overfitting compared to some other models.
# AdaBoost isn’t overly memorizing the training data like some models that hit perfect R² on train but wobble on test.
#
# 🔹 While it may not have the absolute lowest RMSE, it could be more stable and reliable across unseen data.
#
# 🔹 It’s a strong candidate if your goal is robustness rather than squeezing every last drop of accuracy.

# %%
# Initialize models
gb_model = GradientBoostingRegressor(random_state=42)
ada_model = AdaBoostRegressor(random_state=42)

# Run 5-fold cross-validation
gb_scores = cross_val_score(gb_model, X, y, cv=5, scoring='neg_root_mean_squared_error')
ada_scores = cross_val_score(ada_model, X, y, cv=5, scoring='neg_root_mean_squared_error')

# Convert to positive RMSE
print("Gradient Boosting CV RMSE:", -gb_scores.mean())
print("AdaBoost CV RMSE:", -ada_scores.mean())
# Out:
# Gradient Boosting CV RMSE: 1893.7454501472544
# AdaBoost CV RMSE: 3117.6072605797044

# %% [markdown]
# Gradient Boosting is outperforming AdaBoost quite decisively in cross-validation, with a much lower RMSE. While AdaBoost looked promising in terms of stability between train and test, Gradient Boosting has the edge in predictive precision across folds.
# Gradient Boosting is your most efficient learner for this task, especially if your goal is minimizing forecast error.
#
# 📉 AdaBoost is more cautious, but that extra bias might not be worth the hit in accuracy (~+1200 units of RMSE).

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# #### Gradient Boosting

# %%
#Define hyperparameter distribution (use reasonable ranges to avoid too large a search space)
Parameter_Trials = {
    'n_estimators': [100, 150, 200],
    'learning_rate': [0.1, 0.5],
    'max_depth': [10, 14],
    'min_samples_split': [3, 6],
    'min_samples_leaf': [1, 2],
    'subsample': [0.3, 0.5]
}

# Perform RandomizedSearchCV
model = RandomizedSearchCV(gb_reg, Parameter_Trials, n_iter = 10, cv = 5, n_jobs = -1)

# Fit the model
model.fit(X_train_scaled,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingRegressor(max_depth=6),
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.1, 0.5],
#                                         'max_depth': [10, 14],
#                                         'min_samples_leaf': [1, 2],
#                                         'min_samples_split': [3, 6],
#                                         'n_estimators': [100, 150, 200],
#                                         'subsample': [0.3, 0.5]})

# %%
# Get the best hyperparameters
best_gb_params = model.best_params_

# %%
# Get the best model
best_model = model.best_estimator_

# %%
# Evaluate the best model on the test set
best_pred_gb = best_model.predict(X_test_scaled)

print("MAE", mean_absolute_error(best_pred_gb, y_test))
print("RMSE", mean_squared_error(best_pred_gb, y_test, squared=False))
print("R2 score", best_model.score(X_test_scaled, y_test))
print("MAPE", mean_absolute_percentage_error(best_pred_gb, y_test))
# Out:
# MAE 17.54694532272286
# RMSE 334.3678695119096
# R2 score 0.9995382919185696
# MAPE 0.01340751930668157
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Define metrics
metrics = ["MAE", "RMSE", "R²"]
baseline_values = [
    mean_absolute_error(pred_gb, y_test),
    mean_squared_error(pred_gb, y_test, squared=False),
    gb_reg.score(X_test_scaled, y_test)
]
tuned_values = [
    mean_absolute_error(y_test, best_pred_gb),
    mean_squared_error(y_test, best_pred_gb, squared=False),
    best_model.score(X_test_scaled, y_test)
]

# Set position of bars
x = np.arange(len(metrics))
width = 0.3

# Create figure
plt.figure(figsize=(8, 5))
plt.bar(x - width/2, baseline_values, width, label="Baseline Gradient Boosting", color="grey")
plt.bar(x + width/2, tuned_values, width, label="Tuned GB", color="Green")

# Add labels
plt.xticks(x, metrics)
plt.ylabel("Score")
plt.title("Performance Comparison: Baseline vs Hyperparameter Tuning Gradient Boosting")
plt.legend(loc="upper right", ncol=1)  # Horizontal legend

# Show values on bars
for i in range(len(metrics)):
    plt.text(i - width/2, baseline_values[i] + 0.02, f"{baseline_values[i]:.2f}", ha='center', fontsize=12)
    plt.text(i + width/2, tuned_values[i] + 0.02, f"{tuned_values[i]:.2f}", ha='center', fontsize=12)

# Show chart
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
print("Train R²:", best_model.score(X_train_scaled, y_train))
# Out:
# Train R²: 0.999899715331618

# %% [markdown]
# #### AdaBoost

# %%
# Define base estimator
base_tree = DecisionTreeRegressor()
# Proper AdaBoost initialization with tree estimator (for scikit-learn ≥1.2)
ada_reg = AdaBoostRegressor(estimator=base_tree, random_state=42)

# Define hyperparameter distribution
Parameter_Trials = {
    'n_estimators': [300, 400, 500],               
    'learning_rate': [0.05, 0.01, 0.02],         
    'estimator__max_depth': [5, 8, 12],           
    'estimator__min_samples_split': [3, 4, 5],   
    'estimator__min_samples_leaf': [1, 2, 3]      
}

# Perform randomized search
model_ab = RandomizedSearchCV(ada_reg, Parameter_Trials, n_iter=10, cv=5, n_jobs=-1)

# Fit the model
model_ab.fit(X_train_scaled, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=AdaBoostRegressor(estimator=DecisionTreeRegressor(),
#                                                random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'estimator__max_depth': [5, 8, 12],
#                                         'estimator__min_samples_leaf': [1, 2,
#                                                                         3],
#                                         'estimator__min_samples_split': [3, 4,
#                                                                          5],
#                                         'learning_rate': [0.05, 0.01, 0.02],
#                                         'n_estimators': [300, 400, 500]})

# %%
# Get the best hyperparameters
best_ada_params= model_ab.best_params_
best_ada_params
# Out:
# {'n_estimators': 400,
#  'learning_rate': 0.01,
#  'estimator__min_samples_split': 4,
#  'estimator__min_samples_leaf': 3,
#  'estimator__max_depth': 12}

# %%
# After tuning AdaBoost
best_ada_model = model_ab.best_estimator_

# %%
# Evaluate the best model on the test set
best_pred_ada = best_ada_model.predict(X_test_scaled)

print("MAE", mean_absolute_error(best_pred_ada, y_test))
print("RMSE", mean_squared_error(best_pred_ada, y_test, squared=False))
print("R2 score", best_ada_model.score(X_test_scaled, y_test))
print("MAPE", mean_absolute_percentage_error(best_pred_ada, y_test))
# Out:
# MAE 20.781414897893683
# RMSE 360.1907869832274
# R2 score 0.999464223574406
# MAPE 0.012942174039068884
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Define metrics
metrics = ["MAE", "RMSE", "R²"]

baseline_values = [
    mean_absolute_error(y_test, pred_ada),
    mean_squared_error(y_test, pred_ada, squared=False),
    best_model.score(X_test_scaled, y_test)
]
tuned_values = [
    mean_absolute_error(y_test, best_pred_ada),
    mean_squared_error(y_test, best_pred_ada, squared=False),
    best_ada_model.score(X_test_scaled, y_test)
]


# Set position of bars
x = np.arange(len(metrics))
width = 0.3

# Create figure
plt.figure(figsize=(8, 5))
plt.bar(x - width/2, baseline_values, width, label="Baseline AdaBoost", color="grey")
plt.bar(x + width/2, tuned_values, width, label="Tuned AdaBoost", color="Green")

# Add labels
plt.xticks(x, metrics)
plt.ylabel("Score")
plt.title("Performance Comparison: Baseline vs Hyperparameter Tuning AdaBoost")
plt.legend(loc="upper right", ncol=1)  # Horizontal legend

# Show values on bars
for i in range(len(metrics)):
    plt.text(i - width/2, baseline_values[i] + 0.02, f"{baseline_values[i]:.2f}", ha='center', fontsize=12)
    plt.text(i + width/2, tuned_values[i] + 0.02, f"{tuned_values[i]:.2f}", ha='center', fontsize=12)

# Show chart
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ### New results based on the model predictions

# %%
df_new = df_active.drop(columns=['forecast', 'mape', 'absolute_error'], errors='ignore')

# %%
# Rebuild feature matrix using same feature set and encoding
features = ['sales_lag_3', 'forecast_lag_3', 'log_sales', 'pf_segmentation', 'market_segmentation']
X_new = pd.get_dummies(df_new[features])

# Align columns with training data (optional safety step)
X_new = X_new.reindex(columns=X.columns, fill_value=0)

# Scale using the existing scaler
X_new_scaled = scaler.transform(X_new)

# %%
df_new['gb_forecast'] = best_model.predict(X_new_scaled)
df_new['ada_forecast'] = best_ada_model.predict(X_new_scaled)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
# Absolute Error
df_new['gb_absolute_error'] = abs(df_new['sales'] - df_new['gb_forecast'])
df_new['ada_absolute_error'] = abs(df_new['sales'] - df_new['ada_forecast'])

# Row-level MAPE (with zero-handling)
df_new['gb_mape'] = (df_new['gb_absolute_error'] / df_new['sales']).replace([np.inf, -np.inf], np.nan).fillna(0)

df_new['ada_mape'] = (df_new['ada_absolute_error'] / df_new['sales']).replace([np.inf, -np.inf], np.nan).fillna(0)

df_new['gb_mape'] = df_new['gb_mape'] * 100
df_new['ada_mape'] = df_new['ada_mape'] * 100

df_new[['gb_mape', 'ada_mape']] = df_new[['gb_mape', 'ada_mape']].round(2)
df_new[['gb_absolute_error', 'ada_absolute_error']] = df_new[['gb_absolute_error', 'ada_absolute_error']].round(2)

# %%
def choose_best_forecast(row):
    # Prefer lower absolute error
    if row['gb_absolute_error'] < row['ada_absolute_error']:
        return row['gb_forecast']
    elif row['gb_absolute_error'] > row['ada_absolute_error']:
        return row['ada_forecast']
    else:
        # If absolute error is tied, choose lower MAPE
        return row['gb_forecast'] if row['gb_mape'] < row['ada_mape'] else row['ada_forecast']

df_new['final_forecast'] = df_new.apply(choose_best_forecast, axis=1)

# Final absolute error per row
df_new['final_abs_error'] = abs(df_new['sales'] - df_new['final_forecast'])

# Final MAPE per row
df_new['final_mape'] = np.abs(df_new['final_abs_error']) / df_new['sales'] * 100

# %%
def model_used(row):
    if row['gb_absolute_error'] < row['ada_absolute_error']:
        return 'Gradient Boosting'
    elif row['gb_absolute_error'] > row['ada_absolute_error']:
        return 'AdaBoost'
    else:
        return 'Gradient Boosting' if row['gb_mape'] < row['ada_mape'] else 'AdaBoost'

df_new['model_used'] = df_new.apply(model_used, axis=1)

# %%
df_new.to_csv('forecast_evaluation.csv', index=False)

# %%
df_new.groupby('seg_combo')[['gb_mape', 'ada_mape', 'gb_absolute_error','ada_absolute_error']].mean().round(2)
# Out:
#                            gb_mape  ada_mape  gb_absolute_error  \
# seg_combo
# Secure_Major MCO              0.90      0.91               0.32
# Secure_Regular MCO            1.33      1.44               0.53
# Secure_Top MCO                1.36      1.59               0.70
# Supply Growth_Major MCO       1.50      1.78               0.53
# Supply Growth_Regular MCO     2.18      2.28               0.93
# Supply Growth_Top MCO         1.23      1.29              27.49
#
#                            ada_absolute_error
# seg_combo
# Secure_Major MCO                         0.49
# Secure_Regular MCO                       0.63
# Secure_Top MCO                           0.94
# Supply Growth_Major MCO                  0.80
# Supply Growth_Regular MCO                0.95
# Supply Growth_Top MCO                   19.33

# %%
#Check statistical summary
num_cols = ['sales', 'gb_forecast', 'ada_forecast','final_forecast','gb_absolute_error','ada_absolute_error','final_abs_error', 'gb_mape', 'ada_mape', 'final_mape']

df_new[num_cols].describe()
# Out:
#                sales    gb_forecast   ada_forecast  final_forecast  \
# count   16104.000000   16104.000000   16104.000000    16104.000000
# mean     1798.942809    1799.228522    1798.071663     1799.258769
# std     12880.827806   12888.644041   12852.351914    12883.227627
# min         1.000000      -5.141740       2.057239        1.582820
# 25%        47.000000      47.247334      46.933884       46.933884
# 50%       186.000000     186.580487     185.837838      186.107620
# 75%       754.000000     753.291582     752.880000      753.291582
# max    383242.000000  370793.815833  375879.000000   375879.000000
#
#        gb_absolute_error  ada_absolute_error  final_abs_error       gb_mape  \
# count       16104.000000        16104.000000     16104.000000  16104.000000
# mean            6.676952            4.970005         2.422524      1.393726
# std           184.656382          161.066848        80.960195      5.958670
# min             0.000000            0.000000         0.000000      0.000000
# 25%             0.120000            0.110000         0.051697      0.030000
# 50%             0.260000            0.400000         0.140566      0.090000
# 75%             0.400000            0.800000         0.352009      0.550000
# max         12448.180000        14762.000000      7363.000000    224.360000
#
#            ada_mape    final_mape
# count  16104.000000  16104.000000
# mean       1.528985      0.935982
# std        8.901325      5.039299
# min        0.000000      0.000000
# 25%        0.060000      0.021483
# 50%        0.150000      0.057245
# 75%        0.400000      0.233249
# max      105.720000    105.723906

# %% [markdown]
# Mean Absolute Error (~5) looks low on average, but...
#
# Std Dev of Absolute Error (~150–180) shows wide variability.
#
# MAPE ranges up to 107%, meaning some predictions miss entirely.
#
# Highly skewed sales data (max = 383k, mean = 1.8k): this imbalance can hurt model learning.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Aggregate MAPE by GMID
mape_by_gmid = df_new.groupby('gmid')[['gb_mape', 'ada_mape']].mean().sort_values(by='gb_mape', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=mape_by_gmid.index[:15], y=mape_by_gmid['gb_mape'][:15], color='blue', label='GB MAPE')
sns.barplot(x=mape_by_gmid.index[:15], y=mape_by_gmid['ada_mape'][:15], color='green', alpha=0.6, label='AdaBoost MAPE')

plt.title('Top GMIDs with Highest Average MAPE')
plt.xlabel('GMID')
plt.ylabel('Average MAPE (%)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_monthly = df_new.groupby('date')[['gb_mape', 'ada_mape']].mean().reset_index()

plt.figure(figsize=(14, 6))
plt.plot(df_monthly['date'], df_monthly['gb_mape'], label='GB MAPE', color='blue')
plt.plot(df_monthly['date'], df_monthly['ada_mape'], label='Ada MAPE', color='green')
plt.title('Monthly Average MAPE')
plt.xlabel('Date')
plt.ylabel('MAPE (%)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# That chart reveals a great deal, Vera. You're clearly seeing a tale of two models:
#
# 🟩 AdaBoost MAPE jumps all over the place—notice those early spikes around Aug 2023 and intermittent volatility.
#
# 🔷 Gradient Boosting MAPE sits nearly flat, impressively low and stable the entire time.
#
# This reinforces your summary stats: AdaBoost has much higher mean and standard deviation of error, likely due to sensitivity to low-volume sales or noise in certain features. GB, on the other hand, seems much more robust.

# %%
# 📊 Prepare data: average GB MAPE per date and geography
df_geo_monthly_gb = (
    df_new.groupby(['date', 'geography'])['gb_mape']
    .mean()
    .reset_index()
)

# 🎨 Plot setup
plt.figure(figsize=(16, 8))

# 🔁 Plot one line per geography
for geo in df_geo_monthly_gb['geography'].unique():
    df_subset = df_geo_monthly_gb[df_geo_monthly_gb['geography'] == geo]
    plt.plot(df_subset['date'], df_subset['gb_mape'], label=geo)

# 🏷️ Chart styling
plt.title('📊 Gradient Boosting MAPE Over Time by Geography', fontsize=18)
plt.xlabel('Date', fontsize=13)
plt.ylabel('Average GB MAPE (%)', fontsize=13)
plt.xticks(rotation=45)
plt.legend(title='Geography', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

# 🚀 Show it!
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/2771693467.py:23: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout()
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📊 Prepare data: average Ada MAPE per date and geography
df_geo_monthly_gb = (
    df_new.groupby(['date', 'geography'])['ada_mape']
    .mean()
    .reset_index()
)

# 🎨 Plot setup
plt.figure(figsize=(16, 8))

# 🔁 Plot one line per geography
for geo in df_geo_monthly_gb['geography'].unique():
    df_subset = df_geo_monthly_gb[df_geo_monthly_gb['geography'] == geo]
    plt.plot(df_subset['date'], df_subset['ada_mape'], label=geo)

# 🏷️ Chart styling
plt.title('📊 AdaBoost MAPE Over Time by Geography', fontsize=18)
plt.xlabel('Date', fontsize=13)
plt.ylabel('Average GB MAPE (%)', fontsize=13)
plt.xticks(rotation=45)
plt.legend(title='Geography', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

# 🚀 Show it!
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/1361402714.py:23: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout()
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Ensure 'log_segment' exists and is correctly ordered
segment_order = ['Very Low', 'Low-Mid', 'Mid-High', 'Very-High']

# Calculate average MAPE by log segment (using df_active)
mape_by_segment = df_new.groupby('log_segment')['gb_mape'].mean().reindex(segment_order)

# Create the plot
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df_new, x='log_segment', order=segment_order, palette='viridis')

# Annotate each bar with count and MAPE
for p, segment_name in zip(ax.patches, segment_order):
    height = p.get_height()
    xpos = p.get_x() + p.get_width() / 2.

    # Add count label above the bar
    ax.text(xpos, height + 50, f'{int(height)}', ha='center', fontsize=11, fontweight='bold')

    # Add MAPE label inside the bar
    mape_val = mape_by_segment.get(segment_name, np.nan)
    ax.text(xpos, height / 2, f'MAPE: {mape_val:.1f}%', ha='center', va='center',
            fontsize=10, color='white', fontweight='bold')

# Formatting
plt.title("Active Product Count by Log-Based Segment with Average GB MAPE")
plt.xlabel("Log-Based Sales Segment")
plt.ylabel("Count of Records")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/421486284.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mape_by_segment = df_new.groupby('log_segment')['gb_mape'].mean().reindex(segment_order)
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/421486284.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df_new, x='log_segment', order=segment_order, palette='viridis')

# %%
high_error_df = df_new[df_new['gb_absolute_error'] > 100]
high_error_df
# Out:
#               gmid_key       date  year  month  product_family    gmid  \
# 924   110003_202310_US 2023-10-01  2023     10              11  110003
# 2121  120002_202311_US 2023-11-01  2023     11              12  120002
# 2151  120002_202412_US 2024-12-01  2024     12              12  120002
# 2194   120002_20252_US 2025-02-01  2025      2              12  120002
# 2197   120002_20253_US 2025-03-01  2025      3              12  120002
# ...                ...        ...   ...    ...             ...     ...
# 9046  150177_202412_JP 2024-12-01  2024     12              15  150177
# 9055   150177_20251_JP 2025-01-01  2025      1              15  150177
# 9057   150177_20253_JP 2025-03-01  2025      3              15  150177
# 9058   150177_20254_JP 2025-04-01  2025      4              15  150177
# 9059   150177_20255_JP 2025-05-01  2025      5              15  150177
#
#      country         market      geography   sales  ...  log_segment  \
# 924       US  United States  North America   29111  ...    Very-High
# 2121      US  United States  North America   17071  ...    Very-High
# 2151      US  United States  North America   21281  ...    Very-High
# 2194      US  United States  North America   19598  ...    Very-High
# 2197      US  United States  North America   23406  ...    Very-High
# ...      ...            ...            ...     ...  ...          ...
# 9046      JP          Japan    Key Markets  187528  ...    Very-High
# 9055      JP          Japan    Key Markets  155060  ...    Very-High
# 9057      JP          Japan    Key Markets  166215  ...    Very-High
# 9058      JP          Japan    Key Markets  197274  ...    Very-High
# 9059      JP          Japan    Key Markets  168486  ...    Very-High
#
#                   seg_combo  sales_lag_3 forecast_lag_3    gb_forecast  \
# 924          Secure_Top MCO      28656.0        31199.0   29443.014210
# 2121  Supply Growth_Top MCO        764.0            0.0   16966.561792
# 2151  Supply Growth_Top MCO         21.0            0.0   21168.099166
# 2194  Supply Growth_Top MCO       1000.0          300.0   19422.837867
# 2197  Supply Growth_Top MCO        301.0          251.0   23299.588413
# ...                     ...          ...            ...            ...
# 9046  Supply Growth_Top MCO     139266.0       183468.0  187652.191236
# 9055  Supply Growth_Top MCO     181517.0       191396.0  154550.634103
# 9057  Supply Growth_Top MCO     187528.0       222238.0  161718.378143
# 9058  Supply Growth_Top MCO     155060.0       182884.0  197121.170105
# 9059  Supply Growth_Top MCO     142694.0       179587.0  168296.922459
#
#        ada_forecast  gb_absolute_error ada_absolute_error gb_mape  ada_mape
# 924    29226.000000             332.01             115.00    1.14      0.40
# 2121   16974.000000             104.44              97.00    0.61      0.57
# 2151   21230.666667             112.90              50.33    0.53      0.24
# 2194   19505.666667             175.16              92.33    0.89      0.47
# 2197   23417.666667             106.41              11.67    0.45      0.05
# ...             ...                ...                ...     ...       ...
# 9046  187528.000000             124.19               0.00    0.07      0.00
# 9055  155060.000000             509.37               0.00    0.33      0.00
# 9057  164502.000000            4496.62            1713.00    2.71      1.03
# 9058  197274.000000             152.83               0.00    0.08      0.00
# 9059  168486.000000             189.08               0.00    0.11      0.00
#
# [76 rows x 27 columns]

# %%
high_mape_df = df_new[df_new['gb_mape'] > 10]
high_mape_df
# Out:
#                gmid_key       date  year  month  product_family    gmid  \
# 3      100001_202311_NZ 2023-11-01  2023     11               1  100001
# 105     100004_20247_NZ 2024-07-01  2024      7               1  100004
# 157     100006_20237_AU 2023-07-01  2023      7               1  100006
# 464     100019_20249_HK 2024-09-01  2024      9               1  100019
# 553     100023_20253_KR 2025-03-01  2025      3               1  100023
# ...                 ...        ...   ...    ...             ...     ...
# 17488   800072_20253_MA 2025-03-01  2025      3               8  800072
# 17489   800072_20254_MA 2025-04-01  2025      4               8  800072
# 17490   800072_20255_MA 2025-05-01  2025      5               8  800072
# 17555   900002_20249_SG 2024-09-01  2024      9               9  900002
# 17557   900002_20251_NZ 2025-01-01  2025      1               9  900002
#
#       country       market      geography  sales  ...  log_segment  \
# 3          NZ  New Zealand  International      3  ...     Very Low
# 105        NZ  New Zealand  International      4  ...     Very Low
# 157        AU    Australia  International      2  ...     Very Low
# 464        HK    Hong Kong  Greater China      3  ...     Very Low
# 553        KR        Korea  International      4  ...     Very Low
# ...       ...          ...            ...    ...  ...          ...
# 17488      MA      Morocco  International      3  ...     Very Low
# 17489      MA      Morocco  International      1  ...     Very Low
# 17490      MA      Morocco  International      2  ...     Very Low
# 17555      SG    Singapore  International      4  ...     Very Low
# 17557      NZ  New Zealand  International      3  ...     Very Low
#
#                 seg_combo  sales_lag_3 forecast_lag_3 gb_forecast  \
# 3      Secure_Regular MCO         93.0          108.0    3.437234
# 105    Secure_Regular MCO        246.0          252.0    4.416925
# 157    Secure_Regular MCO          0.0            0.0    2.457825
# 464    Secure_Regular MCO         75.0           71.0    3.437234
# 553      Secure_Major MCO         64.0          110.0    4.416925
# ...                   ...          ...            ...         ...
# 17488  Secure_Regular MCO          0.0            0.0    3.437234
# 17489  Secure_Regular MCO          0.0            0.0    1.582820
# 17490  Secure_Regular MCO          0.0            0.0    2.457825
# 17555  Secure_Regular MCO          9.0           13.0    4.416925
# 17557  Secure_Regular MCO        509.0          467.0    3.437234
#
#       ada_forecast  gb_absolute_error ada_absolute_error gb_mape  ada_mape
# 3         2.145985               0.44               0.85   14.57     28.47
# 105       4.447674               0.42               0.45   10.42     11.19
# 157       2.057239               0.46               0.06   22.89      2.86
# 464       2.145985               0.44               0.85   14.57     28.47
# 553       4.447674               0.42               0.45   10.42     11.19
# ...            ...                ...                ...     ...       ...
# 17488     2.145985               0.44               0.85   14.57     28.47
# 17489     2.057239               0.58               1.06   58.28    105.72
# 17490     2.057239               0.46               0.06   22.89      2.86
# 17555     4.447674               0.42               0.45   10.42     11.19
# 17557     2.145985               0.44               0.85   14.57     28.47
#
# [508 rows x 27 columns]

# %%
# Count and average error by country
error_by_country = (
    high_mape_df.groupby('country')['gb_absolute_error']
    .agg(['count', 'mean'])
    .sort_values(by='mean', ascending=False)
)

# Count and average error by product family
error_by_pf = (
    high_mape_df.groupby('product_family')['gb_absolute_error']
    .agg(['count', 'mean'])
    .sort_values(by='mean', ascending=False)
)

# Count and average error by segment_combo
error_by_segment = (
    high_mape_df.groupby('seg_combo')['gb_absolute_error']
    .agg(['count', 'mean'])
    .sort_values(by='mean', ascending=False)
)

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    x=error_by_country.index,
    y=error_by_country['mean'],
    palette='coolwarm'
)

plt.title('Avg GB Absolute Error by Geography (High Error Cases)', fontsize=16)
plt.xlabel('Geography', fontsize=12)
plt.ylabel('Mean Absolute Error', fontsize=12)
plt.xticks(rotation=0)

# 💬 Add value labels on top of bars
for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height:.1f}',       # format to 1 decimal place
        ha='center',
        va='bottom',
        fontsize=10,
        color='black'
    )

plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/3825279805.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    x=error_by_pf.index,
    y=error_by_pf['mean'],
    palette='viridis'
)

plt.title('Avg GB Absolute Error by Product Family', fontsize=16)
plt.xlabel('Product Family', fontsize=12)
plt.ylabel('Mean Absolute Error', fontsize=12)
plt.xticks(rotation=0)

# 💬 Add text annotations above each bar
for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height:.1f}',     # Format to 1 decimal place
        ha='center',
        va='bottom',
        fontsize=10,
        color='black'
    )

plt.tight_layout()
plt.show()
# Out:
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/3805015932.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
df_corr = df_new[['sales', 'gb_mape', 'ada_mape','gb_forecast' ,'ada_forecast','gb_absolute_error', 'gb_absolute_error','log_sales']].corr()
sns.heatmap(df_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation with Error Metrics')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Improve Model

# %%
#Flag Current Month Spikes Directly
#Capture one-off anomalies using plain thresholds:

df_new['flag_mape_spike'] = df_new['gb_mape'] > 18
df_new['flag_abs_error_spike'] = df_new['gb_absolute_error'] > 100

# Filter rows where either MAPE or Absolute Error flag is triggered
spikes = df_new[
    (df_new['flag_mape_spike']) | (df_new['flag_abs_error_spike'])
]

# Show relevant details for inspection
outliers[['date', 'gmid', 'country', 'geography', 'product_family', 'seg_combo',
     'gb_mape', 'gb_absolute_error',
     'flag_mape_spike', 'flag_abs_error_spike']]
# Out:
#           date    gmid country      geography  product_family  \
# 1058  Jul 2023  110009      AT    Key Markets              11
# 3748  Sep 2023  140004      CZ  International              14
# 3749  Oct 2023  140004      FI    Key Markets              14
# 3777  Dec 2023  140004      AT    Key Markets              14
# 4953  Mar 2024  140053      AR  International              14
# ...        ...     ...     ...            ...             ...
# 9057  Apr 2024  150177      JP    Key Markets              15
# 9058  May 2024  150177      JP    Key Markets              15
# 9059  Jun 2024  150177      JP    Key Markets              15
# 9128  Jun 2024  150185      IT    Key Markets              15
# 9129  Jul 2024  150185      IT    Key Markets              15
#
#                   seg_combo  gb_mape  gb_absolute_error  flag_mape_spike  \
# 1058         Secure_Top MCO    14.76               0.15            False
# 3748     Secure_Regular MCO    14.76               0.15            False
# 3749         Secure_Top MCO     1.33               0.09            False
# 3777         Secure_Top MCO    14.76               0.15            False
# 4953     Secure_Regular MCO    14.76               0.15            False
# ...                     ...      ...                ...              ...
# 9057  Supply Growth_Top MCO     2.29            3805.32            False
# 9058  Supply Growth_Top MCO     0.03              53.39            False
# 9059  Supply Growth_Top MCO     0.01              19.14            False
# 9128  Supply Growth_Top MCO     5.73               0.11            False
# 9129  Supply Growth_Top MCO    14.76               0.15            False
#
#       flag_abs_error_spike
# 1058                 False
# 3748                 False
# 3749                 False
# 3777                 False
# 4953                 False
# ...                    ...
# 9057                  True
# 9058                 False
# 9059                 False
# 9128                 False
# 9129                 False
#
# [64 rows x 10 columns]

# %%
#Flag Rolling Error (Persistent Issues)

# rolling(3).mean() is smoothing the error signals to detect persistently poor performers, not just one-off spikes.

# Calculate rolling metrics for each GMID
df_new['gb_mape_rolling3'] = df_new.groupby('gmid')['gb_mape'].transform(lambda x: x.rolling(3).mean())
df_new['gb_abs_error_rolling3'] = df_new.groupby('gmid')['gb_absolute_error'].transform(lambda x: x.rolling(3).mean())

# Flag outliers if error persists
df_new['flag_mape_outlier'] = df_new['gb_mape_rolling3'] > 10
df_new['flag_abs_error_outlier'] = df_new['gb_abs_error_rolling3'] > 100



# Filter rows where either MAPE or Absolute Error flag is triggered
outliers = df_new[
    (df_new['flag_mape_outlier']) |
    (df_new['flag_abs_error_outlier'])
]

# Show relevant details for inspection
outliers[['date', 'gmid', 'country', 'geography', 'product_family', 'seg_combo',
                'gb_mape_rolling3', 'gb_abs_error_rolling3',
                'flag_mape_outlier', 'flag_abs_error_outlier']]
# Out:
#           date    gmid country      geography  product_family  \
# 1058  Jul 2023  110009      AT    Key Markets              11
# 3748  Sep 2023  140004      CZ  International              14
# 3749  Oct 2023  140004      FI    Key Markets              14
# 3777  Dec 2023  140004      AT    Key Markets              14
# 4953  Mar 2024  140053      AR  International              14
# ...        ...     ...     ...            ...             ...
# 9057  Apr 2024  150177      JP    Key Markets              15
# 9058  May 2024  150177      JP    Key Markets              15
# 9059  Jun 2024  150177      JP    Key Markets              15
# 9128  Jun 2024  150185      IT    Key Markets              15
# 9129  Jul 2024  150185      IT    Key Markets              15
#
#                   seg_combo  gb_mape_rolling3  gb_abs_error_rolling3  \
# 1058         Secure_Top MCO         11.003333               0.133333
# 3748     Secure_Regular MCO         10.460000               0.130000
# 3749         Secure_Top MCO         10.283333               0.130000
# 3777         Secure_Top MCO         10.143333               0.126667
# 4953     Secure_Regular MCO         10.460000               0.130000
# ...                     ...               ...                    ...
# 9057  Supply Growth_Top MCO          0.766667            1273.023333
# 9058  Supply Growth_Top MCO          0.773333            1287.143333
# 9059  Supply Growth_Top MCO          0.776667            1292.616667
# 9128  Supply Growth_Top MCO         11.750000               0.136667
# 9129  Supply Growth_Top MCO         11.750000               0.136667
#
#       flag_mape_outlier  flag_abs_error_outlier
# 1058               True                   False
# 3748               True                   False
# 3749               True                   False
# 3777               True                   False
# 4953               True                   False
# ...                 ...                     ...
# 9057              False                    True
# 9058              False                    True
# 9059              False                    True
# 9128               True                   False
# 9129               True                   False
#
# [64 rows x 10 columns]

# %%
#Create Master Flag Column
df_new['forecast_flagged'] = (
    df_new['flag_mape_spike'] |
    df_new['flag_abs_error_spike'] |
    df_new['flag_mape_outlier'] |
    df_new['flag_abs_error_outlier']
)
df_new.head()
# Out:
#            gmid_key      date  year  month  product_family    gmid country  \
# 6   100001_20237_AU  Jul 2023  2023      7               1  100001      AU
# 7   100001_20237_NZ  Aug 2023  2023      7               1  100001      NZ
# 8   100001_20238_AU  Sep 2023  2023      8               1  100001      AU
# 9   100001_20238_NZ  Oct 2023  2023      8               1  100001      NZ
# 10  100001_20239_AU  Nov 2023  2023      9               1  100001      AU
#
#          market      geography  sales  ...  gb_mape  ada_mape  gb_mape_capped  \
# 6     Australia  International     75  ...     0.05      0.07            0.05
# 7   New Zealand  International     29  ...     0.21      1.03            0.21
# 8     Australia  International     66  ...     0.04      0.26            0.04
# 9   New Zealand  International     26  ...     0.41      1.83            0.41
# 10    Australia  International     48  ...     0.10      1.02            0.10
#
#    gb_mape_rolling3 gb_abs_error_rolling3 flag_mape_outlier  \
# 6               NaN                   NaN             False
# 7               NaN                   NaN             False
# 8          0.100000              0.043333             False
# 9          0.220000              0.066667             False
# 10         0.183333              0.063333             False
#
#     flag_abs_error_outlier flag_mape_spike flag_abs_error_spike  \
# 6                    False           False                False
# 7                    False           False                False
# 8                    False           False                False
# 9                    False           False                False
# 10                   False           False                False
#
#     forecast_flagged
# 6              False
# 7              False
# 8              False
# 9              False
# 10             False
#
# [5 rows x 35 columns]

# %%
outliers = df_new[df_new['forecast_flagged']]
outliers.to_csv('outliers.csv', index=False)

# %%
df_flagged = df_new[df_new['forecast_flagged']]
print(df_flagged['sales'].describe())
# Out:
# count        73.000000
# mean     104488.287671
# std      116191.204642
# min           1.000000
# 25%         472.000000
# 50%       71931.000000
# 75%      195270.000000
# max      383242.000000
# Name: sales, dtype: float64

# %%
print(df_flagged['seg_combo'].value_counts())
# Out:
# seg_combo
# Supply Growth_Top MCO        61
# Secure_Regular MCO            5
# Supply Growth_Regular MCO     4
# Secure_Top MCO                3
# Name: count, dtype: int64

# %% [markdown]
# Highly skewed sales distribution:
#
# Min = 1, Max = 383K, Mean = 104K, Median = ~72K.
#
# So... there's a mix of ultra-low and ultra-high volume GMIDs. This means MAPE may be distorted in low-volume cases, and absolute error explodes in high-volume ones.
#
# Segment imbalance:
#
# Supply Growth_Top MCO dominates with 61 out of 73 rows.
#
# You’re not working with a uniform population—this is a targeted niche, possibly with unique demand drivers.

# %% [markdown]
# ### ML Model to enhance flagged Forecast and Absolute Error outliers

# %%
df_model = df_flagged.copy()

le_country = LabelEncoder()
le_seg = LabelEncoder()

df_model['country_encoded'] = le_country.fit_transform(df_model['country'])
df_model['seg_combo_encoded'] = le_seg.fit_transform(df_model['seg_combo'])

X_new = df_model[['sales_lag_3', 'forecast_lag_3', 'country_encoded',
                      'product_family', 'seg_combo_encoded']]
y_new = df_model['log_sales']

# %% [markdown]
# #### Gradient Boosting

# %%
gb_model = GradientBoostingRegressor(n_estimators=100, max_depth=3)
gb_model.fit(X_new, y_new)

# Predict and evaluate
y_pred_gb = gb_model.predict(X_new)

# Undo the log1p transformation
y_true = np.expm1(y_new)         # Actual sales
y_pred = np.expm1(y_pred_gb)     # Predicted sales


mae = mean_absolute_error(y_true, y_pred)
rmse = mean_squared_error(y_true, y_pred, squared=False)
r2 = r2_score(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)

print("Gradient Bossting Evaluation in Sales Scale:")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2 Score: {r2:.3f}")
print(f"MAPE: {mape*100:.2f}%")
# Out:
# Gradient Bossting Evaluation in Sales Scale:
# MAE: 8495.17
# RMSE: 15770.26
# R2 Score: 0.981
# MAPE: 13.80%
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# #### AdaBoost

# %%
ada_model = AdaBoostRegressor(n_estimators=100)
ada_model.fit(X_new, y_new)

# Predict and evaluate
y_pred_ada = ada_model.predict(X_new)

# Undo the log1p transformation
y_true_ab = np.expm1(y_new)         # Actual sales
y_pred_ab = np.expm1(y_pred_ada)     # Predicted sales


mae_ab = mean_absolute_error(y_true_ab, y_pred_ab)
rmse_ab = mean_squared_error(y_true_ab, y_pred_ab, squared=False)
r2_ab = r2_score(y_true_ab, y_pred_ab)
mape_ab = mean_absolute_percentage_error(y_true_ab, y_pred_ab)

print("AdaBoost Evaluation in Sales Scale:")
print(f"MAE: {mae_ab:.2f}")
print(f"RMSE: {rmse_ab:.2f}")
print(f"R2 Score: {r2_ab:.3f}")
print(f"MAPE: {mape_ab*100:.2f}%")
# Out:
# adaBoost Evaluation in Sales Scale:
# MAE: 66383.55
# RMSE: 104611.09
# R2 Score: 0.178
# MAPE: 86.10%
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# #### LightGBM

# %%
lgbm_model = LGBMRegressor()
lgbm_model.fit(X_new, y_new)

# Predict and evaluate
y_pred_log = lgbm_model.predict(X_new) 

# Convert predictions back to sales scale
y_true_lgbm = np.expm1(y_new)
y_pred_lgbm = np.expm1(y_pred_log)

# Evaluate performance
mae_lgbm = mean_absolute_error(y_true_lgbm, y_pred_lgbm)
rmse_lgbm = mean_squared_error(y_true_lgbm, y_pred_lgbm, squared=False)
r2_lgbm = r2_score(y_true_lgbm, y_pred_lgbm)
mape_lgbm = mean_absolute_percentage_error(y_true_lgbm, y_pred_lgbm)

print("LightGBM Evaluation in Sales Scale:")
print(f"MAE: {mae_lgbm:.2f}")
print(f"RMSE: {rmse_lgbm:.2f}")
print(f"R2 Score: {r2_lgbm:.3f}")
print(f"MAPE: {mape_lgbm*100:.2f}%")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52
# [LightGBM] [Info] Number of data points in the train set: 73, number of used features: 3
# [LightGBM] [Info] Start training from score 8.583535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM Evaluation in Sales Scale:
# MAE: 78890.48
# RMSE: 123444.60
# R2 Score: -0.144
# MAPE: 4126.54%
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5, 6],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.4, 0.6, 0.8]
}

search = RandomizedSearchCV(
    GradientBoostingRegressor(), 
    param_distributions=param_grid, 
    n_iter=10, 
    cv=3, 
    scoring='neg_mean_absolute_error'
)

search.fit(X_new, y_new)
# Out:
# RandomizedSearchCV(cv=3, estimator=GradientBoostingRegressor(),
#                    param_distributions={'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [3, 4, 5, 6],
#                                         'n_estimators': [100, 200, 300],
#                                         'subsample': [0.4, 0.6, 0.8]},
#                    scoring='neg_mean_absolute_error')

# %%
# Get the best hyperparameters
print(search.best_params_)
# Out:
# {'subsample': 0.6, 'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.1}

# %%
# Get the best model
best_gb_model = search.best_estimator_

# %%
y_pred_log_best = best_gb_model.predict(X_new)
y_pred_best = np.expm1(y_pred_log_best)
y_true = np.expm1(y_new)

mae = mean_absolute_error(y_true, y_pred_best)
mape = mean_absolute_percentage_error(y_true, y_pred_best)
r2 = r2_score(y_true, y_pred_best)

print(f"\n Evaluation of Best GB Model:")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape*100:.2f}%")
print(f"R² Score: {r2:.3f}")
# Out:
#  Evaluation of Best GB Model:
# MAE: 2978.60
# MAPE: 4.83%
# R² Score: 0.998

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import make_scorer, mean_absolute_percentage_error
import numpy as np

# Convert back from log-sales to actual scale after each fold
def mape_expm1(model, X, y_log):
    y_pred_log = model.predict(X)
    y_pred = np.expm1(y_pred_log)
    y_true = np.expm1(y_log)
    return mean_absolute_percentage_error(y_true, y_pred)

# Wrap custom scorer
custom_mape = make_scorer(mape_expm1, greater_is_better=False)

# Instantiate the model with best parameters (or default for now)
gb_model = GradientBoostingRegressor(n_estimators=100, max_depth=3)

# Run cross-validation
scores = cross_val_score(gb_model, X_new, y_new, cv=5, scoring='r2')  # Use 'r2', 'neg_mean_absolute_error', or custom scorer

# Show results
print("Cross-Validation R² Scores:", scores)
print("Mean R²:", np.mean(scores).round(3))
print("Std Dev:", np.std(scores).round(3))
# Out:
# Cross-Validation R² Scores: [ 0.09098881 -0.34011772  0.98899824  0.10741125  0.03843977]
# Mean R²: 0.177
# Std Dev: 0.438

# %%
#segments
segments = {
    seg: df_model[df_model['seg_combo'] == seg]
    for seg in df_model['seg_combo'].unique()
}

# %%
#models
models_to_test = {
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, max_depth=3),
    'AdaBoost': AdaBoostRegressor(n_estimators=100),
    'XGBoost': xgb.XGBRegressor(n_estimators=100, max_depth=3),
    'KNN': KNeighborsRegressor(n_neighbors=5)
}

# %%
#evaluation loop

results = []

for segment_name, df_model in segments.items():
    if len(df_model) < 5:
        continue  # Skip tiny segments
    X = df_model[['sales_lag_3', 'forecast_lag_3', 'country_encoded', 'seg_combo_encoded']]
    y_log = df_model['log_sales']
    y_true = np.expm1(y_log)
    
    for model_name, model in models_to_test.items():
        model.fit(X, y_log)
        y_pred_log = model.predict(X)
        y_pred = np.expm1(y_pred_log)
        
        mae = mean_absolute_error(y_true, y_pred)
        rmse = mean_squared_error(y_true, y_pred, squared=False)
        r2 = r2_score(y_true, y_pred)
        mape = mean_absolute_percentage_error(y_true, y_pred)

        results.append({
            'Segment': segment_name,
            'Model': model_name,
            'MAE': round(mae, 2),
            'RMSE': round(rmse, 2),
            'R2': round(r2, 3),
            'MAPE (%)': round(mape * 100, 2)
        })

# %%
for seg_name, df_seg in segments.items():
    print(seg_name, len(df_seg))
# Out:
# Supply Growth_Regular MCO 4

# %%
print(df_results.columns.tolist())
# Out:
# []

# %%
df_results = pd.DataFrame(results)
df_results.sort_values(['Segment', 'MAPE (%)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/4g/4yj9rs3x2mxd3r_wz6p0pv080000gn/T/ipykernel_1653/4273143165.py in ?()
#       1 df_results = pd.DataFrame(results)
# ----> 2 df_results.sort_values(['Segment', 'MAPE (%)'])
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7168                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7169                 f" != length of by ({len(by)})"
#    7170             )
#    7171         if len(by) > 1:
# -> 7172             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7173
#    7174             # need to rewrap columns in Series to apply key function
#    7175             if key is not None:
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'Segment'

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# Filter segment
df_seg = segment_sgtmco  
X_seg = df_seg[['sales_lag_3', 'forecast_lag_3', 'country_encoded', 'seg_combo_encoded']]
y_seg = df_seg['log_sales']

param_grid = {
    'n_estimators': [300, 500, 700],
    'max_depth': [4, 5, 6],
    'learning_rate': [0.02, 0.05, 0.1],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'reg_alpha': [0, 0.01],
    'reg_lambda': [0.1, 1]
}


search = RandomizedSearchCV(
    estimator=xgb.XGBRegressor(),
    param_distributions=param_grid,
    scoring='neg_mean_absolute_error',  # or 'r2'
    cv=3,
    n_iter=20,
    verbose=1,
    random_state=42
)

search.fit(X_seg, y_seg)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None, ...),
#                    n_iter=20,
#                    param_distributions={'colsample_bytree': [0.8, 1.0],
#                                         'learning_rate': [0.02, 0.05, 0.1],
#                                         'max_depth': [4, 5, 6],
#                                         'n_estimators': [300, 500, 700],
#                                         'reg_alpha': [0, 0.01],
#                                         'reg_lambda': [0.1, 1],
#                                         'subsample': [0.8, 0.9, 1.0]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=1)

# %%
# Get the best hyperparameters
best_xgb_params = search.best_params_

# %%
# Best model and parameters
best_xgb_model = search.best_estimator_

# %%
# Predict on training set (or split if needed)
y_pred_log = best_xgb_model.predict(X_seg)
y_true_sales = np.expm1(y_seg)
y_pred_sales = np.expm1(y_pred_log)

mae = mean_absolute_error(y_true_sales, y_pred_sales)
rmse = mean_squared_error(y_true_sales, y_pred_sales, squared=False)
r2 = r2_score(y_true_sales, y_pred_sales)
mape = mean_absolute_percentage_error(y_true_sales, y_pred_sales)

print("\nTuned XGBoost Evaluation for Supply Growth_Top MCO:")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.3f}")
print(f"MAPE: {mape*100:.2f}%")
# Out:
# Tuned XGBoost Evaluation for Supply Growth_Top MCO:
# MAE: 10616.59
# RMSE: 17946.72
# R² Score: 0.976
# MAPE: 18.72%
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Feature setup
X_seg = segment_sgtmco[['sales_lag_3', 'forecast_lag_3', 'country_encoded', 'seg_combo_encoded']]
y_log = segment_sgtmco['log_sales']

# Extract tree parameters
tree_params = {key.split('__')[1]: value for key, value in best_ada_params.items() if key.startswith('estimator__')}
# Extract AdaBoost parameters
ada_params = {key: value for key, value in best_ada_params.items() if not key.startswith('estimator__')}
# Reconstruct base tree with best parameters
best_base_tree = DecisionTreeRegressor(**tree_params)

# Train models
xgb_model = xgb.XGBRegressor(**best_xgb_params)
gb_model = GradientBoostingRegressor(**best_gb_params)
ada_model = AdaBoostRegressor(estimator=best_base_tree, **ada_params)

xgb_model.fit(X_seg, y_log)
gb_model.fit(X_seg, y_log)
ada_model.fit(X_seg, y_log)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=12,
#                                                   min_samples_split=3),
#                   learning_rate=0.005, n_estimators=250)

# %%
# Get predictions from both models
xgb_pred_log = xgb_model.predict(X_seg)
gb_pred_log = gb_model.predict(X_seg)
ada_pred_log = ada_model.predict(X_seg)

# Blend predictions (weighted or average)
blended_log = 0.80 * gb_pred_log + 0.17 * ada_pred_log + 0.03 * xgb_pred_log  # example:  less accurate


# Convert back to sales
blended_sales = np.expm1(blended_log)
true_sales = np.expm1(y_log)

# %%
mae = mean_absolute_error(true_sales, blended_sales)
rmse = mean_squared_error(true_sales, blended_sales, squared=False)
r2 = r2_score(true_sales, blended_sales)
mape = mean_absolute_percentage_error(true_sales, blended_sales)

print("Blended Model Evaluation:")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.3f}")
print(f"MAPE: {mape*100:.2f}%")
# Out:
# 🔀 Blended Model Evaluation:
# MAE: 2179.78
# RMSE: 5599.14
# R² Score: 0.998
# MAPE: 7.58%
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
results_blending = []

for segment_name, df_seg in segments.items():
    if len(df_seg) < 5:
        continue

    X = df_seg[['sales_lag_3', 'forecast_lag_3', 'country_encoded', 'seg_combo_encoded']]
    y_log = df_seg['log_sales']
    y = np.expm1(y_log)

    # Train GB model
    gb_model = GradientBoostingRegressor(n_estimators=300, max_depth=4, learning_rate=0.05)
    gb_model.fit(X, y_log)
    gb_pred_log = gb_model.predict(X)
    gb_pred = np.expm1(gb_pred_log)

    # Train AB model
    ada_model = AdaBoostRegressor(estimator=base_tree, n_estimators=300, learning_rate=0.05)
    ada_model.fit(X, y_log)
    ada_pred_log = ada_model.predict(X)
    ada_pred = np.expm1(ada_pred_log)

    # Train XGB model
    xgb_model = xgb.XGBRegressor(n_estimators=300, max_depth=4, learning_rate=0.05)
    xgb_model.fit(X, y_log)
    xgb_pred_log = xgb_model.predict(X)
    xgb_pred = np.expm1(xgb_pred_log)

    # Blend predictions
    blend_pred = 0.80 * gb_pred_log + 0.17 * ada_pred_log + 0.03 * xgb_pred_log  

    # Evaluate each
    for label, pred in zip(['Gradient Boosting', 'XGBoost', 'AdaBoost', 'Blended Ensemble'], [gb_pred, xgb_pred, ada_pred, blend_pred]):
        mae = mean_absolute_error(y, pred)
        rmse = mean_squared_error(y, pred, squared=False)
        r2 = r2_score(y, pred)
        mape = mean_absolute_percentage_error(y, pred)

        results_blending.append({
            'Segment': segment_name,
            'Model': label,
            'MAE': round(mae, 2),
            'RMSE': round(rmse, 2),
            'R2': round(r2, 3),
            'MAPE (%)': round(mape * 100, 2)
        })
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
df_blending = pd.DataFrame(results_blending)
best_models = df_blending.sort_values(['Segment', 'MAPE (%)']).groupby('Segment').first().reset_index()
print(best_models)
# Out:
#                  Segment              Model      MAE     RMSE     R2  MAPE (%)
# 0     Secure_Regular MCO  Gradient Boosting     0.00     0.00  1.000      0.00
# 1  Supply Growth_Top MCO           AdaBoost  1502.75  4830.29  0.998      2.18

# %%
def build_segment_model_router(df_flagged, base_tree=None):
    import numpy as np
    import pandas as pd
    from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
    from sklearn.tree import DecisionTreeRegressor
    import xgboost as xgb
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

    results = []
    deployment_router = {}

    # Default base tree for AdaBoost if none provided
    if base_tree is None:
        base_tree = DecisionTreeRegressor()

    # Loop through each segment using proper groupby
    for segment_name, df_seg in df_flagged.groupby('seg_combo'):
        if len(df_seg) < 5:
            continue  # Skip tiny segments

        X = df_seg[['sales_lag_3', 'forecast_lag_3']]
        y_log = df_seg['log_sales']
        y_true = np.expm1(y_log)

        # Define models to test
        model_candidates = {
            'Gradient Boosting': GradientBoostingRegressor(n_estimators=300, max_depth=4, learning_rate=0.05),
            'AdaBoost': AdaBoostRegressor(estimator=base_tree, n_estimators=300, learning_rate=0.05),
            'XGBoost': xgb.XGBRegressor(n_estimators=300, max_depth=4, learning_rate=0.05)
        }

        best_mape = float('inf')
        best_model = None

        # Evaluate each model
        for model_name, model in model_candidates.items():
            model.fit(X, y_log)
            y_pred = np.expm1(model.predict(X))

            mae = mean_absolute_error(y_true, y_pred)
            rmse = mean_squared_error(y_true, y_pred, squared=False)
            r2 = r2_score(y_true, y_pred)
            mape = mean_absolute_percentage_error(y_true, y_pred)

            results.append({
                'Segment': segment_name,
                'Model': model_name,
                'MAE': round(mae, 2),
                'RMSE': round(rmse, 2),
                'R2': round(r2, 3),
                'MAPE (%)': round(mape * 100, 2)
            })

            # Select best model per segment
            if mape < best_mape:
                best_mape = mape
                best_model = model

        deployment_router[segment_name] = best_model

    # Return leaderboard and router dictionary
    leaderboard_df = pd.DataFrame(results).sort_values(['Segment', 'MAPE (%)']).reset_index(drop=True)
    return leaderboard_df, deployment_router

# %%
base_tree = DecisionTreeRegressor(min_samples_split=4, max_depth=6)

leaderboard_df, deployment_router = build_segment_model_router(df_flagged, base_tree=base_tree)

leaderboard_df
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#                  Segment              Model       MAE      RMSE     R2  \
# 0     Secure_Regular MCO  Gradient Boosting      0.00      0.00  1.000
# 1     Secure_Regular MCO           AdaBoost      0.00      0.00  1.000
# 2     Secure_Regular MCO            XGBoost      0.00      0.00  1.000
# 3  Supply Growth_Top MCO  Gradient Boosting   2913.76  13609.29  0.986
# 4  Supply Growth_Top MCO            XGBoost   5600.20  14867.12  0.984
# 5  Supply Growth_Top MCO           AdaBoost  12338.00  22098.10  0.964
#
#    MAPE (%)
# 0      0.00
# 1      0.00
# 2      0.00
# 3    140.26
# 4    141.83
# 5    419.11
